# %%
# Import Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ##### **1. Load and Merge Datasets**

# %% [markdown]
# ***Purpose: Load the datasets (static_data, vitals_data, clinical_codes), aggregate vitals_data to the ICU stay level by computing means, and merge all datasets into merged_data***

# %%
# Load and Merge Datasets
# Load the datasets
static_data = pd.read_csv('C:/MIMIC-Extract/output/static_data.csv')
vitals_data = pd.read_hdf('C:/MIMIC-Extract/output/vitals_hourly_data.h5')
clinical_codes = pd.read_hdf('C:/MIMIC-Extract/output/C.h5')

# Step 1a: Aggregate vitals_hourly_data.h5 to the ICU stay level
# Compute the mean of each clinical variable (LEVEL2) over the time series
vitals_agg = vitals_data.groupby('icustay_id').agg({
    (col, 'mean'): 'mean' for col in vitals_data.columns.levels[0] if col != 'hours_in'
})
# Flatten the MultiIndex columns
vitals_agg.columns = [f"{col[0]}_mean" for col in vitals_agg.columns]
vitals_agg = vitals_agg.reset_index()

# Step 1b: Prepare static_data and clinical_codes
static_data = static_data.set_index('icustay_id')

# Drop redundant columns from clinical_codes after setting the index
clinical_codes = clinical_codes.reset_index().set_index('icustay_id')
clinical_codes = clinical_codes.drop(columns=['subject_id', 'hadm_id'], errors='ignore')

# Step 1c: Merge the datasets
merged_data = static_data.join(vitals_agg.set_index('icustay_id'), how='left')
merged_data = merged_data.join(clinical_codes, how='left')

# Reset index to make icustay_id a column
merged_data = merged_data.reset_index()

# Print dataset details
print("Shape of merged dataset:", merged_data.shape)
print("Columns in merged dataset:", merged_data.columns.tolist())
# Out:
# Shape of merged dataset: (34472, 136)
# Columns in merged dataset: ['icustay_id', 'subject_id', 'hadm_id', 'gender', 'ethnicity', 'age', 'insurance', 'admittime', 'diagnosis_at_admission', 'dischtime', 'discharge_location', 'fullcode_first', 'dnr_first', 'fullcode', 'dnr', 'dnr_first_charttime', 'timecmo_chart', 'cmo_first', 'cmo_last', 'cmo', 'deathtime', 'intime', 'outtime', 'los_icu', 'admission_type', 'first_careunit', 'mort_icu', 'mort_hosp', 'hospital_expire_flag', 'hospstay_seq', 'readmission_30', 'Alanine aminotransferase_mean', 'Albumin_mean', 'Albumin ascites_mean', 'Albumin pleural_mean', 'Albumin urine_mean', 'Alkaline phosphate_mean', 'Anion gap_mean', 'Asparate aminotransferase_mean', 'Basophils_mean', 'Bicarbonate_mean', 'Bilirubin_mean', 'Blood urea nitrogen_mean', 'CO2_mean', 'CO2 (ETCO2, PCO2, etc.)_mean', 'Calcium_mean', 'Calcium ionized_mean', 'Calcium urine_mean', 'Cardiac Index_mean', 'Cardiac Output Thermodilution_mean', 'Cardiac Output fick_mean', 'Central Venous Pressure_mean', 'Chloride_mean', 'Chloride urine_mean', 'Cholesterol_mean', 'Cholesterol HDL_mean', 'Cholesterol LDL_mean', 'Creatinine_mean', 'Creatinine ascites_mean', 'Creatinine body fluid_mean', 'Creatinine pleural_mean', 'Creatinine urine_mean', 'Diastolic blood pressure_mean', 'Eosinophils_mean', 'Fibrinogen_mean', 'Fraction inspired oxygen_mean', 'Fraction inspired oxygen Set_mean', 'Glascow coma scale total_mean', 'Glucose_mean', 'Heart Rate_mean', 'Height_mean', 'Hematocrit_mean', 'Hemoglobin_mean', 'Lactate_mean', 'Lactate dehydrogenase_mean', 'Lactate dehydrogenase pleural_mean', 'Lactic acid_mean', 'Lymphocytes_mean', 'Lymphocytes ascites_mean', 'Lymphocytes atypical_mean', 'Lymphocytes atypical CSL_mean', 'Lymphocytes body fluid_mean', 'Lymphocytes percent_mean', 'Lymphocytes pleural_mean', 'Magnesium_mean', 'Mean blood pressure_mean', 'Mean corpuscular hemoglobin_mean', 'Mean corpuscular hemoglobin concentration_mean', 'Mean corpuscular volume_mean', 'Monocytes_mean', 'Monocytes CSL_mean', 'Neutrophils_mean', 'Oxygen saturation_mean', 'Partial pressure of carbon dioxide_mean', 'Partial pressure of oxygen_mean', 'Partial thromboplastin time_mean', 'Peak inspiratory pressure_mean', 'Phosphate_mean', 'Phosphorous_mean', 'Plateau Pressure_mean', 'Platelets_mean', 'Positive end-expiratory pressure_mean', 'Positive end-expiratory pressure Set_mean', 'Post Void Residual_mean', 'Potassium_mean', 'Potassium serum_mean', 'Prothrombin time INR_mean', 'Prothrombin time PT_mean', 'Pulmonary Artery Pressure mean_mean', 'Pulmonary Artery Pressure systolic_mean', 'Pulmonary Capillary Wedge Pressure_mean', 'Red blood cell count_mean', 'Red blood cell count CSF_mean', 'Red blood cell count ascites_mean', 'Red blood cell count pleural_mean', 'Red blood cell count urine_mean', 'Respiratory rate_mean', 'Respiratory rate Set_mean', 'Sodium_mean', 'Systemic Vascular Resistance_mean', 'Systolic blood pressure_mean', 'Temperature_mean', 'Tidal Volume Observed_mean', 'Tidal Volume Set_mean', 'Tidal Volume Spontaneous_mean', 'Total Protein_mean', 'Total Protein Urine_mean', 'Troponin-I_mean', 'Troponin-T_mean', 'Venous PvO2_mean', 'Weight_mean', 'White blood cell count_mean', 'White blood cell count urine_mean', 'pH_mean', 'pH urine_mean', 'icd9_codes']

# %% [markdown]
# #### ***2. Load MIMIC-III Tables***

# %%
# Load MIMIC-III Tables
inputevents_cv = pd.read_csv('C:/MIMIC-III/mimic-iii-clinical-database-1.4/data/INPUTEVENTS_CV.csv')
inputevents_mv = pd.read_csv('C:/MIMIC-III/mimic-iii-clinical-database-1.4/data/INPUTEVENTS_MV.csv')
d_items = pd.read_csv('C:/MIMIC-III/mimic-iii-clinical-database-1.4/data/D_ITEMS.csv')
# Out:
# C:\Users\KhanhChang\AppData\Local\Temp\ipykernel_25240\1388829671.py:2: DtypeWarning: Columns (7,9,17,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   inputevents_cv = pd.read_csv('C:/MIMIC-III/mimic-iii-clinical-database-1.4/data/INPUTEVENTS_CV.csv')

# %% [markdown]
# #### ***3. Identify Interventions in D_ITEMS***

# %% [markdown]
# ***Purpose: Filter the D_ITEMS table to identify ITEMIDs for vasopressors, antibiotics, and sedatives, and confirm their labels and categories.***

# %%
# Identify Interventions in D_ITEMS
# Filter D_ITEMS for relevant categories (Medications, Antibiotics, Sedatives, Vasopressors)
relevant_categories = ['Medications', 'Antibiotics', 'Sedatives', 'Vasopressors']
medication_items = d_items[d_items['CATEGORY'].str.contains('|'.join(relevant_categories), na=False, case=False)]

# Identify ITEMIDs for common interventions
vasopressors = medication_items[medication_items['LABEL'].str.contains('Norepinephrine|Dopamine|Epinephrine', case=False, na=False)]
antibiotics = medication_items[medication_items['LABEL'].str.contains('Vancomycin|Piperacillin|Ceftriaxone', case=False, na=False)]
sedatives = medication_items[medication_items['LABEL'].str.contains('Propofol|Midazolam', case=False, na=False)]

# Create lists of ITEMIDs
vasopressor_itemids = vasopressors['ITEMID'].tolist()
antibiotic_itemids = antibiotics['ITEMID'].tolist()
sedative_itemids = sedatives['ITEMID'].tolist()

# Print the ITEMID lists
print("Vasopressor ITEMIDs:", vasopressor_itemids)
print("Antibiotic ITEMIDs:", antibiotic_itemids)
print("Sedative ITEMIDs:", sedative_itemids)

# Confirm labels for the identified ITEMIDs
print("\nVasopressors:")
print(medication_items[medication_items['ITEMID'].isin(vasopressor_itemids)][['ITEMID', 'LABEL', 'CATEGORY']])
print("\nAntibiotics:")
print(medication_items[medication_items['ITEMID'].isin(antibiotic_itemids)][['ITEMID', 'LABEL', 'CATEGORY']])
print("\nSedatives:")
print(medication_items[medication_items['ITEMID'].isin(sedative_itemids)][['ITEMID', 'LABEL', 'CATEGORY']])
# Out:
# Vasopressor ITEMIDs: [221289, 221662, 221906]
# Antibiotic ITEMIDs: [225855, 225892, 225893, 225798]
# Sedative ITEMIDs: [221668, 222168]
#
# Vasopressors:
#       ITEMID           LABEL     CATEGORY
# 8879  221289     Epinephrine  Medications
# 8891  221662        Dopamine  Medications
# 9553  221906  Norepinephrine  Medications
#
# Antibiotics:
#        ITEMID                            LABEL     CATEGORY
# 9863   225855                      Ceftriaxone  Antibiotics
# 9888   225892                     Piperacillin  Antibiotics
# 9889   225893  Piperacillin/Tazobactam (Zosyn)  Antibiotics
# 10218  225798                       Vancomycin  Antibiotics
#
# Sedatives:
#       ITEMID               LABEL     CATEGORY
# 8892  221668  Midazolam (Versed)  Medications
# 9564  222168            Propofol  Medications

# %% [markdown]
# #### ***4. Analyze all interventions in Cohort***

# %% [markdown]
# ***Purpose: Analyze all interventions in your cohort by extracting unique ITEMIDs from INPUTEVENTS_CV and INPUTEVENTS_MV, mapping them to labels, and calculating the number and proportion of patients who received each intervention.***

# %%
# Analyze All Interventions in Cohort
# Extract unique ITEMIDs from both INPUTEVENTS tables
cv_itemids = inputevents_cv['ITEMID'].unique()
mv_itemids = inputevents_mv['ITEMID'].unique()
all_itemids = set(cv_itemids).union(set(mv_itemids))

# Map ITEMIDs to labels using D_ITEMS
itemid_to_label = d_items[d_items['ITEMID'].isin(all_itemids)][['ITEMID', 'LABEL']].set_index('ITEMID')['LABEL'].to_dict()

# Print all interventions (ITEMID and LABEL)
print("All Interventions Available in INPUTEVENTS_CV and INPUTEVENTS_MV:")
for itemid in sorted(all_itemids):
    label = itemid_to_label.get(itemid, "Unknown")
    print(f"ITEMID: {itemid}, Label: {label}")

# Get unique icustay_ids from merged_data
icustay_ids = merged_data['icustay_id'].unique()

# Filter INPUTEVENTS_CV and INPUTEVENTS_MV to only include your cohort
inputevents_cv = inputevents_cv[inputevents_cv['ICUSTAY_ID'].isin(icustay_ids)]
inputevents_mv = inputevents_mv[inputevents_mv['ICUSTAY_ID'].isin(icustay_ids)]

# Combine CV and MV data
inputevents = pd.concat([
    inputevents_cv[['ICUSTAY_ID', 'ITEMID']],
    inputevents_mv[['ICUSTAY_ID', 'ITEMID']]
])

# Group by ICUSTAY_ID and ITEMID to identify which patients received each intervention
intervention_counts = inputevents.groupby(['ITEMID', 'ICUSTAY_ID']).size().reset_index(name='count')
intervention_presence = intervention_counts.groupby('ITEMID')['ICUSTAY_ID'].nunique().reset_index(name='num_patients')

# Add labels from D_ITEMS
intervention_presence = intervention_presence.merge(
    d_items[['ITEMID', 'LABEL']],
    on='ITEMID',
    how='left'
)

# Calculate the proportion of patients who received each intervention
total_patients = len(icustay_ids)  # 34,472
intervention_presence['proportion'] = intervention_presence['num_patients'] / total_patients

# Sort by number of patients (descending)
intervention_presence = intervention_presence.sort_values(by='num_patients', ascending=False)

# Print the summary
print(f"\nTotal ICU Stays in Cohort: {total_patients}")
print("\nInterventions in Your Cohort (Sorted by Number of Patients):")
print(intervention_presence[['ITEMID', 'LABEL', 'num_patients', 'proportion']].head(10))
# Out:
# All Interventions Available in INPUTEVENTS_CV and INPUTEVENTS_MV:
# ITEMID: 30001, Label: Packed RBC's
# ITEMID: 30002, Label: Whole Blood
# ITEMID: 30003, Label: Aminophylline
# ITEMID: 30004, Label: Washed PRBC's
# ITEMID: 30005, Label: Fresh Frozen Plasma
# ITEMID: 30006, Label: Platelets
# ITEMID: 30007, Label: Cryoprecipitate
# ITEMID: 30008, Label: Albumin 5%
# ITEMID: 30009, Label: Albumin 25%
# ITEMID: 30011, Label: Dextran 40
# ITEMID: 30012, Label: Hespan
# ITEMID: 30013, Label: D5W
# ITEMID: 30014, Label: D5/.2NS
# ITEMID: 30015, Label: D5/.45NS
# ITEMID: 30016, Label: Dextrose 10%
# ITEMID: 30017, Label: Dextrose 20%
# ITEMID: 30018, Label: .9% Normal Saline
# ITEMID: 30020, Label: .45% Normal Saline
# ITEMID: 30021, Label: Lactated Ringers
# ITEMID: 30022, Label: Calcium Chloride
# ITEMID: 30023, Label: Calcium Gluconate
# ITEMID: 30024, Label: Ferrous Sulfate
# ITEMID: 30025, Label: Heparin
# ITEMID: 30026, Label: KCL
# ITEMID: 30027, Label: Magnesium Sulfate
# ITEMID: 30028, Label: MVI
# ITEMID: 30029, Label: Potassium Phosphate
# ITEMID: 30030, Label: Sodium Bicarbonate
# ITEMID: 30031, Label: Thiamine
# ITEMID: 30032, Label: TPN
# ITEMID: 30033, Label: Lipids
# ITEMID: 30034, Label: Water
# ITEMID: 30036, Label: Ensure
# ITEMID: 30040, Label: Amrinone
# ITEMID: 30042, Label: Dobutamine
# ITEMID: 30043, Label: Dopamine
# ITEMID: 30044, Label: Epinephrine
# ITEMID: 30045, Label: Insulin
# ITEMID: 30046, Label: Isuprel
# ITEMID: 30047, Label: Levophed
# ITEMID: 30048, Label: Lidocaine
# ITEMID: 30049, Label: Nitroglycerine
# ITEMID: 30050, Label: Nitroprusside
# ITEMID: 30051, Label: Vasopressin
# ITEMID: 30052, Label: Procainamide
# ITEMID: 30053, Label: Cell Saver
# ITEMID: 30054, Label: Pre-Admission Intake
# ITEMID: 30055, Label: Cath Lab Intake
# ITEMID: 30056, Label: Po Intake
# ITEMID: 30057, Label: Supplement
# ITEMID: 30058, Label: Free Water Bolus
# ITEMID: 30059, Label: GT Flush
# ITEMID: 30060, Label: D5NS
# ITEMID: 30061, Label: D5RL
# ITEMID: 30062, Label: CO Fluid
# ITEMID: 30063, Label: IV Piggyback
# ITEMID: 30065, Label: Sterile Water
# ITEMID: 30066, Label: Carrier
# ITEMID: 30067, Label: HCL
# ITEMID: 30068, Label: Folate
# ITEMID: 30069, Label: Solumedrol
# ITEMID: 30070, Label: Amphotericin B
# ITEMID: 30071, Label: Vivonex
# ITEMID: 30072, Label: Peptamen
# ITEMID: 30073, Label: Impact w/fiber
# ITEMID: 30074, Label: Optimental
# ITEMID: 30075, Label: Deliver 2.0
# ITEMID: 30077, Label: Nepro
# ITEMID: 30078, Label: Respalor
# ITEMID: 30080, Label: Nutrihep
# ITEMID: 30081, Label: Boost
# ITEMID: 30082, Label: Boost Plus
# ITEMID: 30083, Label: Boost High Protein
# ITEMID: 30084, Label: Isocal
# ITEMID: 30085, Label: Isocal HN
# ITEMID: 30086, Label: Ultracal
# ITEMID: 30087, Label: Replete
# ITEMID: 30088, Label: Replete w/fiber
# ITEMID: 30089, Label: Promod
# ITEMID: 30090, Label: Tube Feeding
# ITEMID: 30092, Label: Autotransfusion
# ITEMID: 30093, Label: Factor VIII
# ITEMID: 30094, Label: Other Blood Products
# ITEMID: 30095, Label: TF Residual
# ITEMID: 30096, Label: TPN w/Lipids
# ITEMID: 30097, Label: Aminosyn 3.5%
# ITEMID: 30098, Label: D5 Aminosyn 3.5%
# ITEMID: 30099, Label: PPN
# ITEMID: 30100, Label: Regular Insulin
# ITEMID: 30101, Label: OR Crystalloid
# ITEMID: 30102, Label: OR Colloid
# ITEMID: 30103, Label: OR FFP
# ITEMID: 30104, Label: OR Packed RBC's
# ITEMID: 30105, Label: OR Platelets
# ITEMID: 30106, Label: OR Autologous Blood
# ITEMID: 30107, Label: PACU Colloids
# ITEMID: 30108, Label: PACU Crystalloids
# ITEMID: 30109, Label: PACU PO Intake
# ITEMID: 30110, Label: Aggrastat
# ITEMID: 30111, Label: Amicar
# ITEMID: 30112, Label: Amiodarone
# ITEMID: 30113, Label: Atracurium
# ITEMID: 30114, Label: Cisatracurium
# ITEMID: 30115, Label: Diltiazem
# ITEMID: 30116, Label: Doxacurium
# ITEMID: 30117, Label: Esmolol
# ITEMID: 30118, Label: Fentanyl
# ITEMID: 30119, Label: Epinephrine-k
# ITEMID: 30120, Label: Levophed-k
# ITEMID: 30121, Label: Nitroglycerine-k
# ITEMID: 30122, Label: Labetolol
# ITEMID: 30123, Label: Lasix
# ITEMID: 30124, Label: Midazolam
# ITEMID: 30125, Label: Milrinone
# ITEMID: 30126, Label: Morphine Sulfate
# ITEMID: 30127, Label: Neosynephrine
# ITEMID: 30128, Label: Neosynephrine-k
# ITEMID: 30129, Label: Pancuronium
# ITEMID: 30130, Label: Pentobarbitol
# ITEMID: 30131, Label: Propofol
# ITEMID: 30133, Label: Sandostatin
# ITEMID: 30134, Label: Reopro
# ITEMID: 30135, Label: TPA
# ITEMID: 30138, Label: Vecuronium
# ITEMID: 30139, Label: Valium
# ITEMID: 30140, Label: nan
# ITEMID: 30141, Label: Ativan
# ITEMID: 30142, Label: Integrelin
# ITEMID: 30143, Label: 3% Normal Saline
# ITEMID: 30144, Label: Gastric Meds
# ITEMID: 30146, Label: Aprotinin
# ITEMID: 30147, Label: Haldol
# ITEMID: 30148, Label: Narcan
# ITEMID: 30149, Label: Fentanyl (Conc)
# ITEMID: 30150, Label: Fentanyl Base
# ITEMID: 30151, Label: Ketamine
# ITEMID: 30153, Label: Morphine
# ITEMID: 30159, Label: D5 Ringers Lact.
# ITEMID: 30160, Label: D5 Normal Saline
# ITEMID: 30161, Label: .3% normal Saline
# ITEMID: 30163, Label: Dilaudid
# ITEMID: 30164, Label: Criticare HN
# ITEMID: 30165, Label: Promote
# ITEMID: 30166, Label: Promote w/fiber
# ITEMID: 30167, Label: Precedex
# ITEMID: 30168, Label: Normal Saline_GU
# ITEMID: 30169, Label: Sterile H20_GU
# ITEMID: 30170, Label: Ampho-B_GU
# ITEMID: 30171, Label: Other_GU
# ITEMID: 30172, Label: Natrecor
# ITEMID: 30173, Label: Argatroban
# ITEMID: 30174, Label: Bivalirudin
# ITEMID: 30175, Label: Alcohol 10%
# ITEMID: 30176, Label: .25% Normal Saline
# ITEMID: 30177, Label: Lepirudin
# ITEMID: 30178, Label: Nicardipine
# ITEMID: 30179, Label: PRBC's
# ITEMID: 30180, Label: Fresh Froz Plasma
# ITEMID: 30181, Label: Serum Albumin 5%
# ITEMID: 30184, Label: IVIG
# ITEMID: 30185, Label: .9NS + 1:1 Heparin
# ITEMID: 30186, Label: .45NS + 1:1 Heparin
# ITEMID: 30187, Label: D10W
# ITEMID: 30189, Label: D7.5W
# ITEMID: 30190, Label: NS .9%
# ITEMID: 30191, Label: TPN D5.0
# ITEMID: 30192, Label: TPN D7.0
# ITEMID: 30193, Label: TPN D7.5
# ITEMID: 30194, Label: TPN D9.0
# ITEMID: 30195, Label: TPN D2.5
# ITEMID: 30196, Label: TPN D10.0
# ITEMID: 30197, Label: TPN D11.0
# ITEMID: 30198, Label: TPN D12.0
# ITEMID: 30199, Label: TPN D12.5
# ITEMID: 30200, Label: TPN D15.0
# ITEMID: 30201, Label: TPN D17.0
# ITEMID: 30202, Label: TPN D17.5
# ITEMID: 30203, Label: TPN D20.0
# ITEMID: 30204, Label: TPN D22.5
# ITEMID: 30205, Label: TPN D25.0
# ITEMID: 30207, Label: TPN D30.0
# ITEMID: 30208, Label: Lipids 20%
# ITEMID: 30209, Label: Heparin(10 units/cc)
# ITEMID: 30210, Label: .9NS flush
# ITEMID: 30211, Label: .45NS flush
# ITEMID: 30212, Label: .25NS flush
# ITEMID: 30213, Label: D5W flush
# ITEMID: 30214, Label: D10W flush
# ITEMID: 30221, Label: Br Milk FS NG
# ITEMID: 30225, Label: PE 20 FS NG
# ITEMID: 30226, Label: PE 22 FS NG
# ITEMID: 30227, Label: PE 24 FS NG
# ITEMID: 30230, Label: E 20 3/4s NG
# ITEMID: 30231, Label: E 20 FS NG
# ITEMID: 30232, Label: E 22 FS NG
# ITEMID: 30233, Label: E 24 FS NG
# ITEMID: 30237, Label: E 20 Fe FS NG
# ITEMID: 30238, Label: E 22 Fe FS NG
# ITEMID: 30239, Label: E 24 Fe FS NG
# ITEMID: 30243, Label: Prog FS NG
# ITEMID: 30247, Label: SMA FS NG
# ITEMID: 30248, Label: SMA Fe FS NG
# ITEMID: 30249, Label: Pedialyte Sol NG
# ITEMID: 30253, Label: Isomil FS NG
# ITEMID: 30254, Label: Sterile Water PO
# ITEMID: 30255, Label: 5% Dex Water PO
# ITEMID: 30256, Label: 10% Dex Water PO
# ITEMID: 30260, Label: Br Milk FS PO
# ITEMID: 30264, Label: PE 20 FS PO
# ITEMID: 30265, Label: PE 22 FS PO
# ITEMID: 30266, Label: PE 24 FS PO
# ITEMID: 30270, Label: E 20 FS PO
# ITEMID: 30271, Label: E 22 FS PO
# ITEMID: 30272, Label: E 24 FS PO
# ITEMID: 30276, Label: E 20 Fe FS PO
# ITEMID: 30277, Label: E 22 Fe FS PO
# ITEMID: 30278, Label: E 24 Fe FS PO
# ITEMID: 30282, Label: Pregestimil FS PO
# ITEMID: 30283, Label: Pedialyte Sol PO
# ITEMID: 30287, Label: SMA 20 FS PO
# ITEMID: 30291, Label: SMA 20 Fe FS PO
# ITEMID: 30295, Label: Isomil FS PO
# ITEMID: 30296, Label: Sodium Chloride
# ITEMID: 30297, Label: Potassium Chloride
# ITEMID: 30298, Label: Sodium Acetate
# ITEMID: 30299, Label: Potassium Acetate
# ITEMID: 30300, Label: Calcium Chloride 10%
# ITEMID: 30301, Label: TPN D8
# ITEMID: 30302, Label: HMF
# ITEMID: 30303, Label: MCT
# ITEMID: 30304, Label: Polycose
# ITEMID: 30305, Label: Rice Cereal
# ITEMID: 30306, Label: Dobutamine Drip
# ITEMID: 30307, Label: Dopamine Drip
# ITEMID: 30308, Label: Fentanyl Drip
# ITEMID: 30309, Label: Epinephrine Drip
# ITEMID: 30310, Label: Insulin Drip
# ITEMID: 30312, Label: Prostin VR Drip
# ITEMID: 30313, Label: TPN D14
# ITEMID: 30314, Label: TPN D16
# ITEMID: 30315, Label: .25 NS+0.5:1 Heparin
# ITEMID: 30316, Label: .25 NS +1:1 Heparin
# ITEMID: 30317, Label: D 12.5 W
# ITEMID: 30318, Label: D15W
# ITEMID: 30319, Label: D20W
# ITEMID: 30320, Label: D25W
# ITEMID: 30321, Label: .45NS + .5:1 Heparin
# ITEMID: 30322, Label: D17.5W
# ITEMID: 30323, Label: TPN D6
# ITEMID: 30324, Label: Corn Oil
# ITEMID: 30325, Label: TPN D13.0
# ITEMID: 30326, Label: TPN D18.0
# ITEMID: 30328, Label: D 30W
# ITEMID: 30329, Label: Prosobee
# ITEMID: 30332, Label: Prosobee 1/4s PO
# ITEMID: 30333, Label: Prosobee 1/2s PO
# ITEMID: 30334, Label: Prosobee FS PO
# ITEMID: 30335, Label: Enfamil Powder
# ITEMID: 30336, Label: NeoSure
# ITEMID: 30337, Label: NeoSure Powder
# ITEMID: 30338, Label: Sodium Bicarb Drip
# ITEMID: 30339, Label: NeoSure 24 NG
# ITEMID: 30340, Label: Nutramigen 24 NG
# ITEMID: 30341, Label: Nutramigen NG
# ITEMID: 30342, Label: Pregestimil 24 NG
# ITEMID: 30343, Label: Pregestimil NG
# ITEMID: 30344, Label: Enfamil AddedRice NG
# ITEMID: 30345, Label: EnfAddedRice 24 NG
# ITEMID: 30346, Label: Pregestimil 24 PO
# ITEMID: 30347, Label: NeoSure 24 PO
# ITEMID: 30348, Label: Nutramigen PO
# ITEMID: 30349, Label: Nutramigen 24 PO
# ITEMID: 30350, Label: EnfamilAddedRice PO
# ITEMID: 30351, Label: EnfAddedRice 24 PO
# ITEMID: 30352, Label: 0.9% Normal Saline
# ITEMID: 30353, Label: 0.45% Normal Saline
# ITEMID: 30354, Label: ProBalance
# ITEMID: 30355, Label: S 20 Fe NG
# ITEMID: 30356, Label: S 22 Fe NG
# ITEMID: 30357, Label: S 24 Fe NG
# ITEMID: 30358, Label: SC 20 Fe NG
# ITEMID: 30359, Label: SC 22 Fe NG
# ITEMID: 30360, Label: SC 24 Fe NG
# ITEMID: 30361, Label: Portagen 20 NG
# ITEMID: 30362, Label: Portagen 24 NG
# ITEMID: 30364, Label: Similac Powder
# ITEMID: 30365, Label: Enfacare Powder
# ITEMID: 30366, Label: S 20 Fe PO
# ITEMID: 30367, Label: S 22 Fe PO
# ITEMID: 30368, Label: S 24 Fe PO
# ITEMID: 30369, Label: SC 20 Fe PO
# ITEMID: 30370, Label: SC 22 Fe PO
# ITEMID: 30371, Label: SC 24 Fe PO
# ITEMID: 30372, Label: Alimentum PO
# ITEMID: 30373, Label: Alimentum 24 PO
# ITEMID: 30374, Label: Enfacare
# ITEMID: 30375, Label: Enfacare 24
# ITEMID: 30377, Label: Portagen 20 PO
# ITEMID: 30378, Label: Portagen 24 PO
# ITEMID: 30379, Label: Alimentum
# ITEMID: 30380, Label: Alimentum 24 NG
# ITEMID: 30381, Label: .9NS + 0.5:1 heparin
# ITEMID: 30383, Label: Impact
# ITEMID: 30384, Label: Xigris
# ITEMID: 30385, Label: NeoCate
# ITEMID: 30386, Label: Neocate 24
# ITEMID: 30388, Label: Enfacare NG
# ITEMID: 30389, Label: Enfacare 24 NG
# ITEMID: 30391, Label: Neocate 24 NG
# ITEMID: 30392, Label: NeoSure NG
# ITEMID: 30394, Label: Enfacare PO
# ITEMID: 30395, Label: Enfacare 24 PO
# ITEMID: 30396, Label: Neocate PO
# ITEMID: 30397, Label: Neocate 24 PO
# ITEMID: 30398, Label: NeoSure PO
# ITEMID: 30399, Label: Nutramigen Powder
# ITEMID: 30401, Label: Peptamen 1.5
# ITEMID: 30402, Label: Nutren 2.0
# ITEMID: 30403, Label: Nutren Renal
# ITEMID: 30404, Label: Nutren Pulmonary
# ITEMID: 30405, Label: Ensure Plus
# ITEMID: 40030, Label: MANNITOL
# ITEMID: 40033, Label: DEXTRAN
# ITEMID: 40281, Label: sodium phosphate
# ITEMID: 40283, Label: THAM
# ITEMID: 40327, Label: Mannitol 20%
# ITEMID: 40385, Label: K PHOS
# ITEMID: 40402, Label: protonics
# ITEMID: 40404, Label: endoscopy
# ITEMID: 40423, Label: Bolus
# ITEMID: 40424, Label: free H2O
# ITEMID: 40449, Label: epidural-marcaine
# ITEMID: 40450, Label: EBL
# ITEMID: 40452, Label: C.O.
# ITEMID: 40468, Label: epidural asp
# ITEMID: 40471, Label: r femoral puncture
# ITEMID: 40489, Label: Pericardial fluid
# ITEMID: 40503, Label: readi - cat
# ITEMID: 40504, Label: IV MEDS
# ITEMID: 40505, Label: ph of ogt
# ITEMID: 40506, Label: rectal bag
# ITEMID: 40531, Label: kcl 20 meq ivpb
# ITEMID: 40532, Label: FREE H2O
# ITEMID: 40533, Label: procedure
# ITEMID: 40535, Label: hemodyalysis
# ITEMID: 40548, Label: ALBUMIN
# ITEMID: 40549, Label: protonix
# ITEMID: 40550, Label: PANTOPRAZOLE
# ITEMID: 40551, Label: bicarb push
# ITEMID: 40552, Label: cisatricurium
# ITEMID: 40579, Label: Meperidine
# ITEMID: 40581, Label: CO flush
# ITEMID: 40582, Label: Meperidine cc/hr
# ITEMID: 40583, Label: readi-ct
# ITEMID: 40585, Label: PD total
# ITEMID: 40586, Label: bowel movement
# ITEMID: 40595, Label: na phosphate
# ITEMID: 40596, Label: K-PHOS
# ITEMID: 40598, Label: r leg leaking fluid
# ITEMID: 40611, Label: NA BICARB
# ITEMID: 40632, Label: NS w/ 40K
# ITEMID: 40635, Label: baricat
# ITEMID: 40636, Label: kayexalate PR
# ITEMID: 40645, Label: magnesium
# ITEMID: 40646, Label: JT bile
# ITEMID: 40667, Label: demerol
# ITEMID: 40676, Label: natracor
# ITEMID: 40691, Label: paracentisis
# ITEMID: 40692, Label: ebl cath lab
# ITEMID: 40699, Label: K+ PHOS
# ITEMID: 40700, Label: Pantoprazole
# ITEMID: 40702, Label: free water infusion
# ITEMID: 40712, Label: free H20
# ITEMID: 40713, Label: po contrast
# ITEMID: 40725, Label: supra pubic flush
# ITEMID: 40726, Label: epidural
# ITEMID: 40743, Label: Hematoma Aspiration
# ITEMID: 40744, Label: pad change
# ITEMID: 40749, Label: protonix infusion
# ITEMID: 40750, Label: foley irrigation
# ITEMID: 40752, Label: sp aspirate
# ITEMID: 40777, Label: PROTONIX GTT
# ITEMID: 40778, Label: Free H2O
# ITEMID: 40780, Label: cath lab
# ITEMID: 40788, Label: PD dialysate in
# ITEMID: 40794, Label: Na Phosphate
# ITEMID: 40795, Label: ns bladder
# ITEMID: 40796, Label: Protonix mg/hr
# ITEMID: 40801, Label: plasma pheresis
# ITEMID: 40802, Label: IGG
# ITEMID: 40803, Label: paracenthesis
# ITEMID: 40812, Label: Kphos 30mmol
# ITEMID: 40832, Label: NS/PITOCIN 20U
# ITEMID: 40833, Label: readi cat
# ITEMID: 40850, Label: ns bolus
# ITEMID: 40863, Label: k phos
# ITEMID: 40864, Label: KPhos
# ITEMID: 40865, Label: NS BOLUS
# ITEMID: 40866, Label: Cath Lab Ouput
# ITEMID: 40872, Label: free water
# ITEMID: 40873, Label: FREE H20 NG
# ITEMID: 40880, Label: Kphos
# ITEMID: 40889, Label: OCTREOTIDE
# ITEMID: 40894, Label: hemopytsis
# ITEMID: 40895, Label: L neck mass aspirate
# ITEMID: 40902, Label: Demerol
# ITEMID: 40903, Label: pad changes
# ITEMID: 40907, Label: dialysate
# ITEMID: 40908, Label: c.o.
# ITEMID: 40929, Label: radiographin
# ITEMID: 40952, Label: c.0. fluid
# ITEMID: 40953, Label: intake from paper
# ITEMID: 40954, Label: Xigris 20mg/100mL
# ITEMID: 40955, Label: Left Hip Aspiration
# ITEMID: 40957, Label: right abdomen
# ITEMID: 40958, Label: cardiac ouput fluid
# ITEMID: 40963, Label: pheresis
# ITEMID: 40964, Label: Ara-c chemo gtt
# ITEMID: 40976, Label: FLOLAN
# ITEMID: 40989, Label: Thorancentisis
# ITEMID: 40998, Label: go-lytley
# ITEMID: 41000, Label: OR intake
# ITEMID: 41001, Label: Angio intake
# ITEMID: 41002, Label: TPA .5mg/hr
# ITEMID: 41014, Label: Soduim Phospate
# ITEMID: 41028, Label: Pigtail Flush
# ITEMID: 41048, Label: EMERGENCY DEPT
# ITEMID: 41063, Label: PD Dialysate Intake
# ITEMID: 41064, Label: Ca Gluc
# ITEMID: 41065, Label: d5w 10gm ca+ glucon
# ITEMID: 41066, Label: d5w & 6gm ca+ glucon
# ITEMID: 41067, Label: K Phos
# ITEMID: 41068, Label: Liperudin
# ITEMID: 41076, Label: MgSO4
# ITEMID: 41077, Label: HD fluid off
# ITEMID: 41083, Label: lr with pictocin
# ITEMID: 41084, Label: ED intake
# ITEMID: 41086, Label: GoLytely
# ITEMID: 41087, Label: pad
# ITEMID: 41089, Label: PERI PAD
# ITEMID: 41092, Label: ED INTAKE
# ITEMID: 41093, Label: Cyclosporin
# ITEMID: 41094, Label: bx site
# ITEMID: 41100, Label: Flowlan
# ITEMID: 41101, Label: Protonix
# ITEMID: 41110, Label: IV Isuprel 1mcg/min
# ITEMID: 41111, Label: METHYLPRED 450MG/HR
# ITEMID: 41121, Label: C.O. fluid
# ITEMID: 41122, Label: HD
# ITEMID: 41147, Label: Dialysate instilled
# ITEMID: 41162, Label: NaPhos
# ITEMID: 41163, Label: Calcium gluc gtt
# ITEMID: 41164, Label: CATH LAB U.O.
# ITEMID: 41174, Label: Altepase
# ITEMID: 41175, Label: PROBALANCE TF
# ITEMID: 41176, Label: Soduim Phosphate
# ITEMID: 41179, Label: ascites fluid bag
# ITEMID: 41182, Label: acetylcysteine 20%
# ITEMID: 41183, Label: Sodium Phosphate
# ITEMID: 41186, Label: NS with Pit 20units
# ITEMID: 41187, Label: Neuro Angio Intake
# ITEMID: 41188, Label: Probalance TF
# ITEMID: 41189, Label: Nicardipine mg/hr
# ITEMID: 41193, Label: cyclosporine
# ITEMID: 41194, Label: OB pad
# ITEMID: 41201, Label: probalance TF
# ITEMID: 41216, Label: go-lytely
# ITEMID: 41217, Label: probalance fs
# ITEMID: 41218, Label: ns+40gm cagluconate
# ITEMID: 41219, Label: pheresis intake
# ITEMID: 41220, Label: hd
# ITEMID: 41234, Label: floor intake
# ITEMID: 41237, Label: ns fluid boluses
# ITEMID: 41246, Label: bladder irrigation
# ITEMID: 41275, Label: golytly
# ITEMID: 41303, Label: cath lab dye
# ITEMID: 41307, Label: Peritoneal Dialysate
# ITEMID: 41322, Label: rl bolus
# ITEMID: 41351, Label: QUINIDINE
# ITEMID: 41352, Label: ER FLUIDS
# ITEMID: 41353, Label: KPHOS
# ITEMID: 41354, Label: PD fluid retained
# ITEMID: 41355, Label: C.O
# ITEMID: 41356, Label: IV Bolus
# ITEMID: 41357, Label: NG aspirate
# ITEMID: 41358, Label: EBL(OR)
# ITEMID: 41367, Label: iv fluid from osh
# ITEMID: 41368, Label: er ivf
# ITEMID: 41371, Label: ns fluid bolus
# ITEMID: 41372, Label: redicat
# ITEMID: 41373, Label: NS for BT
# ITEMID: 41380, Label: nsbolus
# ITEMID: 41381, Label: PLASMAPHERESIS
# ITEMID: 41382, Label: angio in
# ITEMID: 41383, Label: PLASMAPHORESIS
# ITEMID: 41387, Label: CATH LAB DYE
# ITEMID: 41388, Label: CATH LAB FLUID
# ITEMID: 41389, Label: ct contrast
# ITEMID: 41390, Label: barracat
# ITEMID: 41391, Label: k-phos 20mmol/500cc
# ITEMID: 41392, Label: ns b
# ITEMID: 41408, Label: mannitol
# ITEMID: 41409, Label: ED Intake
# ITEMID: 41410, Label: Flolan
# ITEMID: 41413, Label: ready cat
# ITEMID: 41415, Label: lactulose enema
# ITEMID: 41416, Label: free h2o boluses
# ITEMID: 41425, Label: kayexalate pr
# ITEMID: 41427, Label: 1/2 nsfluidbolus
# ITEMID: 41428, Label: ns .9% bolus
# ITEMID: 41429, Label: PD INFUSED
# ITEMID: 41430, Label: free water boluses
# ITEMID: 41431, Label: ampho bladder wash
# ITEMID: 41432, Label: ns pr              e
# ITEMID: 41439, Label: sodium phos
# ITEMID: 41445, Label: NS IN ER
# ITEMID: 41446, Label: RL IN OR
# ITEMID: 41447, Label: Panidronate
# ITEMID: 41448, Label: protonix 8mg/250
# ITEMID: 41449, Label: NS 4gr Ca Gluconate
# ITEMID: 41450, Label: 21mM Potassium Phos
# ITEMID: 41451, Label: NS with 4 gr Ca Gluc
# ITEMID: 41457, Label: Free H20 intake
# ITEMID: 41458, Label: pantopralole
# ITEMID: 41459, Label: 1/4 NS
# ITEMID: 41460, Label: capd dialysate
# ITEMID: 41461, Label: PO contrast
# ITEMID: 41466, Label: before icu ns
# ITEMID: 41467, Label: NS IV bolus
# ITEMID: 41474, Label: capd
# ITEMID: 41485, Label: SODIUM PHOS
# ITEMID: 41490, Label: NS bolus
# ITEMID: 41491, Label: fluid bolus
# ITEMID: 41492, Label: plueral fluid
# ITEMID: 41493, Label: THERMODILUTION FLUID
# ITEMID: 41508, Label: plural fluid
# ITEMID: 41516, Label: versed drip
# ITEMID: 41517, Label: talc in ct
# ITEMID: 41518, Label: bumex
# ITEMID: 41520, Label: paracentsis
# ITEMID: 41524, Label: IVF AT OSH
# ITEMID: 41525, Label: PROTONIX MG/HR
# ITEMID: 41526, Label: 1/2 ns bolus
# ITEMID: 41531, Label: octreotide
# ITEMID: 41532, Label: Pamidronate        l
# ITEMID: 41537, Label: iv protonix
# ITEMID: 41538, Label: enema-lactulose
# ITEMID: 41549, Label: thermoldilution
# ITEMID: 41550, Label: dextrose gtt
# ITEMID: 41555, Label: hd removal
# ITEMID: 41556, Label: ng
# ITEMID: 41557, Label: oral
# ITEMID: 41561, Label: GASTROGRAFFIN
# ITEMID: 41568, Label: Multivitamin
# ITEMID: 41575, Label: ENEMA
# ITEMID: 41579, Label: golytely
# ITEMID: 41580, Label: free h2o bolus
# ITEMID: 41581, Label: Water bolus
# ITEMID: 41582, Label: free h20 bolus
# ITEMID: 41583, Label: pantoprazole
# ITEMID: 41591, Label: kayexolate PR
# ITEMID: 41597, Label: Dextrose 15%
# ITEMID: 41609, Label: Rifampin
# ITEMID: 41610, Label: ER
# ITEMID: 41611, Label: Nesiritide
# ITEMID: 41619, Label: frfee water boluses
# ITEMID: 41620, Label: dialysate in
# ITEMID: 41621, Label: Bannana Bag
# ITEMID: 41622, Label: K-Acetate 40mEq/250
# ITEMID: 41627, Label: pepcid gtt
# ITEMID: 41632, Label: Mannitol
# ITEMID: 41642, Label: contrast
# ITEMID: 41643, Label: 15 mMol KPhos
# ITEMID: 41646, Label: famotidine
# ITEMID: 41651, Label: xygris
# ITEMID: 41652, Label: GO-LYTELY
# ITEMID: 41653, Label: Vanco Enema In:
# ITEMID: 41654, Label: Gastro Graphin
# ITEMID: 41662, Label: hd off
# ITEMID: 41668, Label: mycomust
# ITEMID: 41669, Label: Xygris
# ITEMID: 41676, Label: EW
# ITEMID: 41677, Label: Angio IVF
# ITEMID: 41688, Label: lactulose Enema
# ITEMID: 41689, Label: 15 MMOL NaPHOS
# ITEMID: 41693, Label: Verapamil
# ITEMID: 41694, Label: Verapamil drip
# ITEMID: 41695, Label: NS fluid boluses
# ITEMID: 41697, Label: bal cctn
# ITEMID: 41701, Label: iv intake in angio
# ITEMID: 41702, Label: EW IVF
# ITEMID: 41704, Label: Lactulose Enema
# ITEMID: 41706, Label: irrig for bldr press
# ITEMID: 41709, Label: Kayoxalate Enema
# ITEMID: 41710, Label: glucagon
# ITEMID: 41711, Label: CAPD dialysate dwell
# ITEMID: 41712, Label: CT prep
# ITEMID: 41714, Label: CAPD efluent
# ITEMID: 41721, Label: fee water bolus
# ITEMID: 41726, Label: ascites
# ITEMID: 41732, Label: Mannitol 50Gm/250mL
# ITEMID: 41733, Label: phenobarbital
# ITEMID: 41739, Label: TOTAL IN FROM PAPERT
# ITEMID: 41740, Label: iv fluid since mn
# ITEMID: 41741, Label: TOTAL IN ON PAPER CT
# ITEMID: 41742, Label: Lactulose300mg/NS700
# ITEMID: 41743, Label: water bolus
# ITEMID: 41744, Label: total intake since n
# ITEMID: 41745, Label: H20 BOLUS VIA NG
# ITEMID: 41746, Label: input from midnight
# ITEMID: 41747, Label: i&o by paper
# ITEMID: 41752, Label: uo since mn
# ITEMID: 41757, Label: FLOOR INTAKE
# ITEMID: 41759, Label: BICARB
# ITEMID: 41760, Label: lacutlose enema
# ITEMID: 41761, Label: READYCAT
# ITEMID: 41765, Label: gastrograffin
# ITEMID: 41771, Label: ns w/ 15mmol na+ phs
# ITEMID: 41773, Label: Bari-cat
# ITEMID: 41774, Label: HD putback
# ITEMID: 41776, Label: IR blood products
# ITEMID: 41777, Label: IR intake
# ITEMID: 41779, Label: CSF needle aspirate
# ITEMID: 41780, Label: Paracentisis
# ITEMID: 41787, Label: Peritoneal dial in
# ITEMID: 41788, Label: K+ Phos
# ITEMID: 41789, Label: thoracen fluid
# ITEMID: 41791, Label: 2.5% dialysate in
# ITEMID: 41792, Label: 1.5% dialysate
# ITEMID: 41797, Label: protonix gtt cc/hr
# ITEMID: 41798, Label: TF PROBALANCE
# ITEMID: 41799, Label: Hemo Vol
# ITEMID: 41807, Label: Calcium chloride IVP
# ITEMID: 41808, Label: sodium bicarb IVP
# ITEMID: 41810, Label: plasmaphoresis
# ITEMID: 41814, Label: reaadicat
# ITEMID: 41823, Label: nicardipine gtt
# ITEMID: 41824, Label: D5W 150meq NAHCO3
# ITEMID: 41825, Label: golytlely
# ITEMID: 41827, Label: Dilaudid Epidural
# ITEMID: 41828, Label: nicardipine drip
# ITEMID: 41835, Label: Bicarb gtt
# ITEMID: 41841, Label: ]readi-cat
# ITEMID: 41845, Label: pamidrinate in ns
# ITEMID: 41846, Label: study drug
# ITEMID: 41848, Label: Mucomyst
# ITEMID: 41850, Label: golytle
# ITEMID: 41851, Label: 3/4str impact w/fibr
# ITEMID: 41853, Label: GO LYTELY
# ITEMID: 41855, Label: iv fluid in er
# ITEMID: 41856, Label: Barocet
# ITEMID: 41859, Label: flolan
# ITEMID: 41864, Label: thermodilution fluid
# ITEMID: 41865, Label: injectate
# ITEMID: 41895, Label: Glucagon Gtt
# ITEMID: 41896, Label: ivf boluses
# ITEMID: 41902, Label: angio intake
# ITEMID: 41905, Label: ANGIO INTAKE
# ITEMID: 41906, Label: NA PHOS
# ITEMID: 41913, Label: NS
# ITEMID: 41915, Label: FREE WATER
# ITEMID: 41916, Label: NIMBEX
# ITEMID: 41938, Label: ATG
# ITEMID: 41941, Label: VAC DRESSING
# ITEMID: 41951, Label: ANGIO U/O
# ITEMID: 41956, Label: Potassium
# ITEMID: 41958, Label: KPHOS 30MMOL
# ITEMID: 41962, Label: PRECEDEX CC/HR
# ITEMID: 41963, Label: HCL GTT
# ITEMID: 41968, Label: bicarb drip
# ITEMID: 41981, Label: THAM GTT
# ITEMID: 41983, Label: NAHCO3
# ITEMID: 41984, Label: FREE H20
# ITEMID: 42007, Label: GASTROGRAFIN
# ITEMID: 42024, Label: angio fluids /anes
# ITEMID: 42025, Label: D5.45 60K
# ITEMID: 42026, Label: Flush LT ct #1&2 q8'
# ITEMID: 42027, Label: PROMOTE WIH FIBER
# ITEMID: 42028, Label: PROMOTE WITH FIBER
# ITEMID: 42030, Label: angio ebl
# ITEMID: 42031, Label: angio u/o
# ITEMID: 42038, Label: er crystalloid
# ITEMID: 42039, Label: ANGIO CRYSTALL
# ITEMID: 42040, Label: CISTACURIUM
# ITEMID: 42041, Label: barium sulfate
# ITEMID: 42044, Label: aprotinin cc/hr
# ITEMID: 42045, Label: nimbex mcg/kg/min
# ITEMID: 42047, Label: ebl
# ITEMID: 42049, Label: criticare hn tf
# ITEMID: 42050, Label: promote with fiber
# ITEMID: 42051, Label: AMPHOTERCIN CC HR
# ITEMID: 42052, Label: FREE H20 BOLUS
# ITEMID: 42053, Label: GASTROGAVIN IN H20
# ITEMID: 42058, Label: ER INTAKE
# ITEMID: 42059, Label: promote/fiber
# ITEMID: 42060, Label: METHYLPREDNISONE GTT
# ITEMID: 42061, Label: CBI-NS
# ITEMID: 42062, Label: Precedex (mcg/kg/hr)
# ITEMID: 42063, Label: pamidronate
# ITEMID: 42064, Label: bladder press irrig
# ITEMID: 42065, Label: ASCITIC FLUID
# ITEMID: 42074, Label: TPA 1MG/5CC
# ITEMID: 42076, Label: c scan
# ITEMID: 42079, Label: CONTRAST VIA NG.
# ITEMID: 42082, Label: ANGIO CRYSTALLOIDS
# ITEMID: 42083, Label: PRE ANGIO(PACU)CRYST
# ITEMID: 42084, Label: 1/4STR BETAD. FLUSH
# ITEMID: 42087, Label: NS 40 KCL
# ITEMID: 42088, Label: METROWEST INTAKE
# ITEMID: 42089, Label: K PHOS OVER 6 HRS
# ITEMID: 42090, Label: Promote with fiber
# ITEMID: 42091, Label: impact w/fiber+promo
# ITEMID: 42099, Label: urinary irrigant
# ITEMID: 42100, Label: cistatracurium
# ITEMID: 42102, Label: ER U/O
# ITEMID: 42106, Label: PROMOTE/FIBER
# ITEMID: 42108, Label: ANGIO CRYS
# ITEMID: 42109, Label: REPLACEMENT FLUID
# ITEMID: 42110, Label: ANGIO EBL
# ITEMID: 42112, Label: Old trauma line site
# ITEMID: 42115, Label: iv fluid in angio
# ITEMID: 42116, Label: PROMOTE/w/FIBER
# ITEMID: 42117, Label: THYMOGLOBULIN
# ITEMID: 42118, Label: EBL IN ANGIO
# ITEMID: 42125, Label: ANGIO IN
# ITEMID: 42126, Label: Solumedrol gtt
# ITEMID: 42127, Label: C SCAN
# ITEMID: 42134, Label: cistacur mcq/kg/min
# ITEMID: 42135, Label: IMPACTW/FIBER+PROMOD
# ITEMID: 42136, Label: REDICAT
# ITEMID: 42137, Label: left groin bag
# ITEMID: 42142, Label: FREE WATER/OR D5W
# ITEMID: 42146, Label: APROTONIN
# ITEMID: 42149, Label: ETOH DRIP
# ITEMID: 42150, Label: CRITICARE TF
# ITEMID: 42154, Label: Bile instillation
# ITEMID: 42161, Label: ns w/40 kcl
# ITEMID: 42162, Label: k phosphate iv
# ITEMID: 42163, Label: solumedrol drip
# ITEMID: 42166, Label: bile replacement/q4h
# ITEMID: 42168, Label: breast pumping
# ITEMID: 42171, Label: ANGIO
# ITEMID: 42172, Label: MANITOL
# ITEMID: 42173, Label: aprotonin
# ITEMID: 42174, Label: nimbex cc/hr
# ITEMID: 42175, Label: CONTRAST VIA OG
# ITEMID: 42176, Label: approtinin
# ITEMID: 42177, Label: RT. PIGTAIL
# ITEMID: 42180, Label: CISATRICURIUM
# ITEMID: 42185, Label: Pre admit FFP
# ITEMID: 42186, Label: Pre admit PRBC
# ITEMID: 42187, Label: free h20
# ITEMID: 42188, Label: REDI-CAT
# ITEMID: 42192, Label: CATH LAB CRYST
# ITEMID: 42193, Label: CONTRAST CATH LAB
# ITEMID: 42194, Label: CC7 FLUIDS
# ITEMID: 42197, Label: CC7 HUO
# ITEMID: 42202, Label: gi fluid
# ITEMID: 42203, Label: Aprotonin
# ITEMID: 42204, Label: Protonix gtt
# ITEMID: 42205, Label: contrast via ft
# ITEMID: 42206, Label: .45ns w/ 20kcl
# ITEMID: 42207, Label: Nulytely prep
# ITEMID: 42208, Label: ABDOMINAL SUMP
# ITEMID: 42211, Label: left fem a-line site
# ITEMID: 42213, Label: OR ABDOMINAL DNG
# ITEMID: 42215, Label: CRYS CC7
# ITEMID: 42216, Label: 1/2ST IMPACT W/FIBER
# ITEMID: 42217, Label: peritoneal fluid
# ITEMID: 42221, Label: ER CRYST
# ITEMID: 42223, Label: ns w/40kcl
# ITEMID: 42224, Label: FARR 5 IN
# ITEMID: 42230, Label: NS W/40KCL
# ITEMID: 42231, Label: CRYST ANGIO
# ITEMID: 42232, Label: THYMOGLOBLIN
# ITEMID: 42233, Label: APROTININ 10,000/100
# ITEMID: 42234, Label: HD REMOVAL
# ITEMID: 42235, Label: HUO ANGIO
# ITEMID: 42238, Label: CC7 CRYSTALLOIDS
# ITEMID: 42239, Label: CC7 PRBC
# ITEMID: 42240, Label: SOLUMEDROL DRIP
# ITEMID: 42241, Label: .45NS & 1 AMP BICARB
# ITEMID: 42242, Label: ANGIO CRYSTALLOID
# ITEMID: 42243, Label: anti-thymocyte globu
# ITEMID: 42244, Label: .45ns + 1 amp bicarb
# ITEMID: 42245, Label: CARIPORIDE STUDY
# ITEMID: 42246, Label: CISATRICARIUM CC/HR
# ITEMID: 42249, Label: BRBPR
# ITEMID: 42250, Label: CC7 BRBPR
# ITEMID: 42251, Label: BUPIVICAINE/EPIDURAL
# ITEMID: 42259, Label: lt plural ct bag
# ITEMID: 42265, Label: LR W/ 20 KCL
# ITEMID: 42266, Label: IV fluid Farr5
# ITEMID: 42269, Label: bile replacement
# ITEMID: 42273, Label: vasopressin unit/min
# ITEMID: 42274, Label: gastrogavin in h20
# ITEMID: 42275, Label: bile refeed
# ITEMID: 42277, Label: insensible loss
# ITEMID: 42281, Label: Ice chips
# ITEMID: 42282, Label: na phos
# ITEMID: 42284, Label: CISATRACURIUM DRIP
# ITEMID: 42285, Label: PROTONIX DRIP
# ITEMID: 42286, Label: calicium gluc gtt
# ITEMID: 42288, Label: LR w/40 kcl
# ITEMID: 42291, Label: NIMBEX CC/HR
# ITEMID: 42292, Label: k-phos
# ITEMID: 42295, Label: STURDY HOSP
# ITEMID: 42296, Label: mgso4 gtt
# ITEMID: 42297, Label: Fluid bolus
# ITEMID: 42298, Label: CARIPROSIDE
# ITEMID: 42299, Label: CISATRA
# ITEMID: 42301, Label: NG RESIDUAL
# ITEMID: 42306, Label: ER IVF
# ITEMID: 42307, Label: EW INTAKE
# ITEMID: 42308, Label: STUDY DRUG
# ITEMID: 42309, Label: CISATRA CC/HR
# ITEMID: 42310, Label: cisatricurium cc/hr
# ITEMID: 42311, Label: CONTRAST VIA NG
# ITEMID: 42322, Label: er crystalloids
# ITEMID: 42323, Label: er ffp
# ITEMID: 42324, Label: er prbc
# ITEMID: 42325, Label: CARIPORIDE CC/HR
# ITEMID: 42326, Label: Kphos 15mmol. 250cc
# ITEMID: 42329, Label: er u/o
# ITEMID: 42334, Label: APRTININ CC/HR
# ITEMID: 42335, Label: 1/2 STR. VIVONEX
# ITEMID: 42336, Label: DEXTROSE125GMS/250CC
# ITEMID: 42337, Label: NAHCO3- CC/HR
# ITEMID: 42342, Label: Amiodarone mg/hr
# ITEMID: 42343, Label: CARIPORIDE ML/HR
# ITEMID: 42344, Label: tham
# ITEMID: 42345, Label: LR w/ 40 mEq
# ITEMID: 42352, Label: OR TPN
# ITEMID: 42353, Label: CISTRACURIUM
# ITEMID: 42358, Label: k phos over 6hrs
# ITEMID: 42359, Label: cariporide/ns
# ITEMID: 42360, Label: CATH LAB IV INTAKE
# ITEMID: 42361, Label: cariporide
# ITEMID: 42363, Label: angio crystalloid
# ITEMID: 42364, Label: er iv intake
# ITEMID: 42365, Label: Bupivacaine
# ITEMID: 42369, Label: CONTRAST IN ANGIO
# ITEMID: 42370, Label: CRYSTALLOID IN ANGIO
# ITEMID: 42372, Label: CARIPORIDE
# ITEMID: 42373, Label: SOLUMEDEROL GTT
# ITEMID: 42374, Label: L THIGH JACKSON PRAT
# ITEMID: 42375, Label: U/O IN ANGIO
# ITEMID: 42380, Label: er intake
# ITEMID: 42381, Label: CC6 INTAKE
# ITEMID: 42382, Label: READI-CAT
# ITEMID: 42383, Label: cc for cc replace
# ITEMID: 42384, Label: 90%CC/CC U/O REPLACE
# ITEMID: 42385, Label: Cisatracurium gtt
# ITEMID: 42387, Label: NA+ ACETATE
# ITEMID: 42389, Label: BAG LT LEG
# ITEMID: 42391, Label: right hand bag
# ITEMID: 42395, Label: D5W + 40 KCL
# ITEMID: 42396, Label: ns with 50meq HCL
# ITEMID: 42401, Label: vicu cryst
# ITEMID: 42402, Label: epidural drip
# ITEMID: 42404, Label: vicu u/o
# ITEMID: 42406, Label: GASTROGRAFIN/NG
# ITEMID: 42407, Label: Precedex mcg/kg/hr
# ITEMID: 42408, Label: hcl 50meq/500cc@   0
# ITEMID: 42409, Label: D5LR W/40K
# ITEMID: 42413, Label: NEURO-RAD IN
# ITEMID: 42414, Label: Cisat mcg/kg/min
# ITEMID: 42415, Label: THAM (30 meq=100cc)
# ITEMID: 42416, Label: nabicarb 250/1000
# ITEMID: 42418, Label: INTAKE ON FLOOR
# ITEMID: 42422, Label: SOLUMEDROL DRIPMG/HR
# ITEMID: 42423, Label: heparin via sheaths
# ITEMID: 42424, Label: ANCEF IRRIGATION
# ITEMID: 42428, Label: CARIPORIDE STUDY/CC
# ITEMID: 42429, Label: Free water
# ITEMID: 42430, Label: D5W w/20gm CaGluc
# ITEMID: 42438, Label: CAROPORIDE
# ITEMID: 42439, Label: farr 7 intake
# ITEMID: 42440, Label: 1/2 STR. IMPACT/FIBR
# ITEMID: 42447, Label: 250n/s 15mM NA PHOS
# ITEMID: 42448, Label: ABD wound bag
# ITEMID: 42451, Label: ANTI-THYMOCYTE GLOB
# ITEMID: 42452, Label: PD fluid 2.5%
# ITEMID: 42453, Label: Fluid Bolus
# ITEMID: 42455, Label: FENOLDOPAM 10MG/250C
# ITEMID: 42456, Label: PD Fluid 1.5%
# ITEMID: 42457, Label: PENTOBARB DRIP
# ITEMID: 42458, Label: PD4.5%
# ITEMID: 42459, Label: APROTANIN
# ITEMID: 42462, Label: NEPRO W/ PROMOD
# ITEMID: 42468, Label: angio crystalloids
# ITEMID: 42469, Label: GASTROGAVIN
# ITEMID: 42470, Label: 4.25travasol/5%dex.
# ITEMID: 42471, Label: Other
# ITEMID: 42474, Label: blake
# ITEMID: 42477, Label: PD 1.5%
# ITEMID: 42478, Label: D5W/Ca Gluc 20Gm
# ITEMID: 42480, Label: Cariporide
# ITEMID: 42481, Label: d5w/20g cagluc/L
# ITEMID: 42483, Label: 1000 D5W 20GM CAGLU
# ITEMID: 42484, Label: 1000N/S 20GM CA GLU
# ITEMID: 42488, Label: SODIUM PHOSPHATE
# ITEMID: 42489, Label: farr 7 crystalloid
# ITEMID: 42490, Label: Na Phos
# ITEMID: 42491, Label: Current goal
# ITEMID: 42492, Label: farr 7 u/o
# ITEMID: 42493, Label: k phos. 15mm
# ITEMID: 42494, Label: anti-thymocyte globn
# ITEMID: 42495, Label: nepro with promod
# ITEMID: 42503, Label: Fluid in cath lab
# ITEMID: 42504, Label: CA GLUCONATE
# ITEMID: 42506, Label: OR ASCITES
# ITEMID: 42512, Label: 1000NS/1000UHEPARIN
# ITEMID: 42513, Label: bivalirudin gtt
# ITEMID: 42514, Label: SOLUMEDROL DRIP.
# ITEMID: 42515, Label: antithymocyte globin
# ITEMID: 42521, Label: aprotinen
# ITEMID: 42522, Label: FOLEY FLUSH
# ITEMID: 42526, Label: SOLUMEDROL GTT
# ITEMID: 42527, Label: INR BLOOD PRODUCTS
# ITEMID: 42528, Label: crystalloid farr 5
# ITEMID: 42529, Label: po intake farr5
# ITEMID: 42531, Label: farr 5 u/o
# ITEMID: 42534, Label: c-scan
# ITEMID: 42538, Label: cell saver/or
# ITEMID: 42548, Label: NS Bolus
# ITEMID: 42554, Label: FREE WATER INTAKE
# ITEMID: 42561, Label: ALCOHOL
# ITEMID: 42562, Label: pos. dialysate intak
# ITEMID: 42563, Label: SOLUMEDROL MG/KG/HR
# ITEMID: 42564, Label: ALCOHOL 10%DRIP G/HR
# ITEMID: 42565, Label: TROMETHAMINE CC/HR
# ITEMID: 42566, Label: 1000D5/130NA ACETATE
# ITEMID: 42567, Label: 130meqNAACETATE/D5W
# ITEMID: 42568, Label: R Groin Site
# ITEMID: 42570, Label: OR BILE
# ITEMID: 42573, Label: ACETYLCYSTEINE
# ITEMID: 42574, Label: INTERVENTIONAL RADIY
# ITEMID: 42575, Label: alteplase
# ITEMID: 42576, Label: 10% ALCOHOL DRIP
# ITEMID: 42577, Label: ALCOHOL 5% DRIP G/HR
# ITEMID: 42580, Label: hemovac hip
# ITEMID: 42581, Label: hemovac neck
# ITEMID: 42587, Label: VICU IVF
# ITEMID: 42588, Label: VICU PRBC
# ITEMID: 42589, Label: aprotanin
# ITEMID: 42590, Label: nimbex
# ITEMID: 42596, Label: PENTOBARBITAL
# ITEMID: 42599, Label: banana bag
# ITEMID: 42606, Label: IR CRYSTALLOID
# ITEMID: 42607, Label: THIAME,FOLICACID,MVI
# ITEMID: 42608, Label: Cisat mcg/kg/hr
# ITEMID: 42609, Label: AMPHO-B
# ITEMID: 42610, Label: IR U/O
# ITEMID: 42612, Label: WATER VIA NG
# ITEMID: 42613, Label: gastrogavin
# ITEMID: 42614, Label: Leg bag/serous drg
# ITEMID: 42618, Label: R fem drg site
# ITEMID: 42621, Label: L GROIN HEMOVAC
# ITEMID: 42623, Label: KCL 20mEq bolus
# ITEMID: 42628, Label: potassium phos
# ITEMID: 42629, Label: CELL SAVER IN OR
# ITEMID: 42630, Label: Antithymocyte globu
# ITEMID: 42631, Label: 100mgm ATG/250N/S
# ITEMID: 42638, Label: fenoldopam
# ITEMID: 42639, Label: bolus
# ITEMID: 42640, Label: from flow sheet
# ITEMID: 42641, Label: 3/4st impact w/fiber
# ITEMID: 42645, Label: EW intake
# ITEMID: 42646, Label: HYDRALAZINE IV
# ITEMID: 42647, Label: LOPRESSOR IV
# ITEMID: 42648, Label: VASOTEC IV
# ITEMID: 42654, Label: farr 2 intake
# ITEMID: 42655, Label: METHYLPREDNISOLONE
# ITEMID: 42656, Label: OR EPIDURAL INTAKE
# ITEMID: 42657, Label: corlopam mcgs/kg/min
# ITEMID: 42658, Label: gastroview
# ITEMID: 42660, Label: E.R. CRYSTALLOID
# ITEMID: 42661, Label: ampho b iv
# ITEMID: 42663, Label: 1/2ST IMPACT/FIBER
# ITEMID: 42664, Label: nesirtide
# ITEMID: 42665, Label: GOLYTELY
# ITEMID: 42668, Label: aprotanine
# ITEMID: 42669, Label: KETAMINE MG/HR
# ITEMID: 42671, Label: free h2o
# ITEMID: 42673, Label: EPIDURAL
# ITEMID: 42674, Label: ILIAC HEMOVAC
# ITEMID: 42675, Label: POST NECK HEMOVAC
# ITEMID: 42679, Label: 1/2 H2O/impact fiber
# ITEMID: 42680, Label: Tham infusion
# ITEMID: 42689, Label: METHYLPREDNISONE
# ITEMID: 42691, Label: kphos
# ITEMID: 42692, Label: Angio
# ITEMID: 42693, Label: 20 GM CAGLUC/1L D5W
# ITEMID: 42697, Label: Alcohol Gm/hour
# ITEMID: 42698, Label: NS W/ 40 KCL
# ITEMID: 42699, Label: GU IRRIGANT
# ITEMID: 42702, Label: ns with 40kcl
# ITEMID: 42704, Label: corlopam
# ITEMID: 42705, Label: FENOLDOPAM
# ITEMID: 42706, Label: k phos over 6hrs.
# ITEMID: 42707, Label: d5w w 10% etoh
# ITEMID: 42708, Label: ms04 pca
# ITEMID: 42709, Label: ALCOHOL GTT ML/HR
# ITEMID: 42710, Label: PHERESIS EBL
# ITEMID: 42711, Label: OR OTHER
# ITEMID: 42713, Label: carevue downtime
# ITEMID: 42714, Label: while carevue down
# ITEMID: 42715, Label: CRYSTAL IN/DAY SHIFT
# ITEMID: 42716, Label: angio site
# ITEMID: 42721, Label: 40kcl in 500ns
# ITEMID: 42722, Label: ALCOHOL 10% DRIP
# ITEMID: 42723, Label: cryo
# ITEMID: 42724, Label: 40kcl in 500cc ns
# ITEMID: 42725, Label: NS W/ 40MEQ KCL
# ITEMID: 42728, Label: POTASSIUM
# ITEMID: 42729, Label: GI IVF
# ITEMID: 42730, Label: 15 mmol K phos/250cc
# ITEMID: 42731, Label: Dextran40 10%
# ITEMID: 42732, Label: Fenoldopam
# ITEMID: 42734, Label: APROTININE
# ITEMID: 42735, Label: Intra-abd. Pressure
# ITEMID: 42736, Label: D5W/154MEQ NAACETATE
# ITEMID: 42737, Label: NA PHOS 30MMOL
# ITEMID: 42739, Label: er crystilliods
# ITEMID: 42740, Label: prbc in er
# ITEMID: 42742, Label: 1/2 NS WITH 40 KCL
# ITEMID: 42743, Label: MANNITOL 20%
# ITEMID: 42745, Label: Pigtail irrigant
# ITEMID: 42749, Label: fluid bolus NS
# ITEMID: 42755, Label: atg
# ITEMID: 42756, Label: anti-thomocyte glob.
# ITEMID: 42757, Label: anti-thomcyte glob.
# ITEMID: 42758, Label: open chest suction
# ITEMID: 42762, Label: FARR 6 IN IVF
# ITEMID: 42763, Label: PORK INSULIN GTT
# ITEMID: 42764, Label: PLAMA-LYTE
# ITEMID: 42768, Label: R groin bag
# ITEMID: 42769, Label: Rectal Irrigation
# ITEMID: 42770, Label: Floor intake
# ITEMID: 42771, Label: lepirudim
# ITEMID: 42777, Label: 10% ALCOHOL IN 5% D5
# ITEMID: 42778, Label: HYDROCHLORIC ACID
# ITEMID: 42779, Label: HCL 75 meq/500ml
# ITEMID: 42782, Label: Epidural
# ITEMID: 42783, Label: Prostaglandin
# ITEMID: 42784, Label: cell saver OR
# ITEMID: 42785, Label: OR CRYO
# ITEMID: 42786, Label: WD. DRGE
# ITEMID: 42790, Label: ns w/ 40meq kcl
# ITEMID: 42791, Label: Pheresis - In
# ITEMID: 42792, Label: nepro (1/2) & promod
# ITEMID: 42793, Label: contrast po
# ITEMID: 42797, Label: 20Gm CaGluc/1000ccNS
# ITEMID: 42799, Label: K+ phosphate
# ITEMID: 42801, Label: cell saver in or
# ITEMID: 42802, Label: VASOPRESSIN  CC/HR.
# ITEMID: 42804, Label: ETOH Grams/hour
# ITEMID: 42805, Label: multivitamins
# ITEMID: 42811, Label: Aprotinin cc/hr
# ITEMID: 42812, Label: betadine chest irrig
# ITEMID: 42813, Label: CYCLOSPORIN
# ITEMID: 42814, Label: 3/4 str Impact w/fib
# ITEMID: 42815, Label: PERITONEAL FLUID
# ITEMID: 42820, Label: ed crystalloid
# ITEMID: 42821, Label: aprotinine
# ITEMID: 42825, Label: farr2
# ITEMID: 42826, Label: 10mEqK/100cc
# ITEMID: 42827, Label: D5W/20GM CA GLU
# ITEMID: 42830, Label: OR CELL SAVER
# ITEMID: 42831, Label: 1/2st impact fiber
# ITEMID: 42832, Label: albumin 12.5%
# ITEMID: 42833, Label: 1/2 STR.CRITICARE HN
# ITEMID: 42836, Label: ANGIO IVF
# ITEMID: 42839, Label: other
# ITEMID: 42841, Label: vp shunt
# ITEMID: 42844, Label: NS fluid bolus
# ITEMID: 42845, Label: Angio In
# ITEMID: 42848, Label: sodium bicarb
# ITEMID: 42849, Label: hemovac
# ITEMID: 42855, Label: ETOH GTT
# ITEMID: 42856, Label: CALCIUM GLUGOANTE
# ITEMID: 42857, Label: SODIUM BICARBOANTE
# ITEMID: 42858, Label: FLOOR CRYSTALLOIDS
# ITEMID: 42862, Label: Fendolapam
# ITEMID: 42864, Label: ER CRYSTALLOID
# ITEMID: 42865, Label: Lepriudin
# ITEMID: 42866, Label: cell saver in OR
# ITEMID: 42875, Label: cc6 ivf
# ITEMID: 42876, Label: ER CRYSTALLOIDS
# ITEMID: 42878, Label: IR IN
# ITEMID: 42879, Label: Pre adm-Floor IV
# ITEMID: 42886, Label: NS CT IRRIGATION
# ITEMID: 42887, Label: Travasol
# ITEMID: 42888, Label: D5W 10%ALCOHOL
# ITEMID: 42894, Label: iv contrast
# ITEMID: 42895, Label: MANNITOL 20 %.
# ITEMID: 42896, Label: NS 150MEQ SOD BICARB
# ITEMID: 42897, Label: D5W 300MEQ BICARB
# ITEMID: 42898, Label: D5W 20GMS CA GLUC
# ITEMID: 42899, Label: FLUCONAZOLE
# ITEMID: 42900, Label: L FEM
# ITEMID: 42901, Label: Right brachial site
# ITEMID: 42902, Label: right femerol
# ITEMID: 42908, Label: NS W/ 20 GM CAGLUC
# ITEMID: 42913, Label: angio
# ITEMID: 42914, Label: Total IV
# ITEMID: 42915, Label: D5W/10GM CAGLUC
# ITEMID: 42916, Label: calcium gluc
# ITEMID: 42917, Label: D5W/CAGLU 40GMS
# ITEMID: 42920, Label: EW FLUID
# ITEMID: 42921, Label: d5 .225 with 20meq l
# ITEMID: 42923, Label: Integrellin
# ITEMID: 42924, Label: IR CRYST.
# ITEMID: 42925, Label: L CT SITE
# ITEMID: 42926, Label: IR UO
# ITEMID: 42927, Label: AMPHO B
# ITEMID: 42931, Label: HD in
# ITEMID: 42932, Label: 10% alcohol
# ITEMID: 42933, Label: XYGRIS
# ITEMID: 42935, Label: CT # 6 & # 2 RT
# ITEMID: 42938, Label: IR INTAKE
# ITEMID: 42939, Label: 1/4ns w 100meqnahco3
# ITEMID: 42940, Label: co injectate
# ITEMID: 42941, Label: I.R. EBL
# ITEMID: 42942, Label: I.R. intake
# ITEMID: 42944, Label: dextran
# ITEMID: 42947, Label: ER in
# ITEMID: 42948, Label: CONTRAST VIA NG/FT
# ITEMID: 42949, Label: duodenal
# ITEMID: 42954, Label: Angio IN
# ITEMID: 42955, Label: PLASMAKYTE
# ITEMID: 42956, Label: mucus stoma
# ITEMID: 42959, Label: FS PROBALANCE
# ITEMID: 42965, Label: xigris mcg/kg/hr
# ITEMID: 42967, Label: Nicardipine (mg/h)
# ITEMID: 42971, Label: saturated chux pad
# ITEMID: 42975, Label: DEXTRAN DRIP
# ITEMID: 42976, Label: CATH LAB
# ITEMID: 42978, Label: D5LR 20KCL
# ITEMID: 42979, Label: NS w/30mmol Kphos
# ITEMID: 42980, Label: D5 1/4 SODIUM BICARB
# ITEMID: 42981, Label: Bladder transd.
# ITEMID: 42985, Label: Pamidronate
# ITEMID: 42989, Label: DILAUDID/BUPIV.
# ITEMID: 42990, Label: BUPIVACAINE .50%
# ITEMID: 42993, Label: 10 mea KCL/100cc NS
# ITEMID: 42994, Label: K PHOS 15 MMOL
# ITEMID: 42995, Label: F6 IV MEDS
# ITEMID: 42996, Label: F6 PO INTAKE
# ITEMID: 42998, Label: alcohol gtt
# ITEMID: 42999, Label: Sodium Bicarb
# ITEMID: 43002, Label: F6 U/O
# ITEMID: 43007, Label: MultiVitamin
# ITEMID: 43008, Label: cryo or
# ITEMID: 43009, Label: ffp pacu
# ITEMID: 43010, Label: packed cells pacu
# ITEMID: 43013, Label: ANTI-THYMOCYTEN
# ITEMID: 43014, Label: ER NS BOLUSES
# ITEMID: 43017, Label: NET PD
# ITEMID: 43018, Label: magnesium 1gm/hr
# ITEMID: 43020, Label: TPA 50mg/250cc
# ITEMID: 43021, Label: TPA 50mg/250cc #2
# ITEMID: 43023, Label: probalance 15gm prom
# ITEMID: 43031, Label: steril water
# ITEMID: 43032, Label: 40 kcl in 500ns
# ITEMID: 43033, Label: CALSTAT
# ITEMID: 43036, Label: na phosp 15 mmol
# ITEMID: 43037, Label: nicardipine HCL
# ITEMID: 43038, Label: Noe gtt 60mg/250cc
# ITEMID: 43039, Label: ca gluc gtt
# ITEMID: 43041, Label: FA6 IVF
# ITEMID: 43044, Label: BYPASS REMOVAL
# ITEMID: 43047, Label: BUMEX 12mg/500ml
# ITEMID: 43049, Label: FLOOR IN
# ITEMID: 43050, Label: ca glu 40gm/1L
# ITEMID: 43051, Label: L. GROIN PUNCTURE
# ITEMID: 43055, Label: FARR 6 COLLOID
# ITEMID: 43056, Label: NA PHOS 15MMOL
# ITEMID: 43059, Label: Direct suction
# ITEMID: 43061, Label: 40Gm CaGluc/1000ccNS
# ITEMID: 43062, Label: D5W w/ 40gms cagluc
# ITEMID: 43063, Label: NS w/40gms CaGluc
# ITEMID: 43070, Label: Ca++ Gluconate
# ITEMID: 43073, Label: NaPO4
# ITEMID: 43076, Label: h2o flush q 8hr
# ITEMID: 43077, Label: L. GROIN
# ITEMID: 43080, Label: NS w/30mmol NaPhos
# ITEMID: 43081, Label: QUICKMIX
# ITEMID: 43083, Label: g-t residual
# ITEMID: 43086, Label: Nicardipine gtt
# ITEMID: 43087, Label: 3/4 RESPALOR
# ITEMID: 43088, Label: 1/2str impact/fiber
# ITEMID: 43089, Label: ns w/ 40 meq kcl
# ITEMID: 43090, Label: NICADRDIPINE
# ITEMID: 43091, Label: GALLBLADDER DR FLUSH
# ITEMID: 43092, Label: INTAKE ED
# ITEMID: 43097, Label: vicu intake
# ITEMID: 43107, Label: intake from floor
# ITEMID: 43108, Label: contrast via ng
# ITEMID: 43109, Label: Golytly
# ITEMID: 43112, Label: preadmit to ICU NS
# ITEMID: 43113, Label: SOIDUM PHOSPHATE
# ITEMID: 43118, Label: probalance tf
# ITEMID: 43122, Label: rectal irrigation
# ITEMID: 43125, Label: xigris cc/hr
# ITEMID: 43126, Label: d5w/40 gm ca gluc
# ITEMID: 43131, Label: iv intake
# ITEMID: 43132, Label: RL + 20K/100
# ITEMID: 43134, Label: 1/2 STR IMPACT/FIBER
# ITEMID: 43135, Label: NS/40GM CA GLU
# ITEMID: 43136, Label: DEXMEDETOMIDINE
# ITEMID: 43137, Label: GT, straight, perf'd
# ITEMID: 43139, Label: HCL GTTS 75MEQ/500ML
# ITEMID: 43140, Label: D5W/1L/2AMP BICARB
# ITEMID: 43141, Label: PD
# ITEMID: 43147, Label: 1/2STR PROMOTE/FIBER
# ITEMID: 43168, Label: d10 bolus
# ITEMID: 43169, Label: Bicarb drip
# ITEMID: 43170, Label: TPN D21.5 with hep
# ITEMID: 43228, Label: D10W BOLUS
# ITEMID: 43229, Label: D10 bolus
# ITEMID: 43230, Label: Portagen
# ITEMID: 43232, Label: 1/2 NS flush
# ITEMID: 43233, Label: TPN D10.5 with hep
# ITEMID: 43234, Label: TPND10.5 with hep
# ITEMID: 43235, Label: contrast dye
# ITEMID: 43237, Label: 25% Albumin
# ITEMID: 43238, Label: Potassium Chl. Bolus
# ITEMID: 43240, Label: Portagen w/PoMod NG
# ITEMID: 43241, Label: Portagen 20 cal po
# ITEMID: 43242, Label: portagen
# ITEMID: 43319, Label: Carnation Good Start
# ITEMID: 43320, Label: D10W NSS W/.5Uhep.:
# ITEMID: 43321, Label: D14.5 lytes and hep
# ITEMID: 43322, Label: Lipid tubing change
# ITEMID: 43332, Label: void
# ITEMID: 43346, Label: tpn d13.5 with hepan
# ITEMID: 43353, Label: Albumin (human) 25%
# ITEMID: 43354, Label: normal saline flushs
# ITEMID: 43356, Label: Lt. upper CT
# ITEMID: 43357, Label: Rt. upper CT
# ITEMID: 43364, Label: kcl infusion
# ITEMID: 43366, Label: ur.cc/kg/hr
# ITEMID: 43367, Label: Portagen NG
# ITEMID: 43370, Label: Portagen 24
# ITEMID: 43381, Label: cc/kg/hr
# ITEMID: 43387, Label: Fentanyl bolus:
# ITEMID: 43394, Label: Similac
# ITEMID: 43395, Label: 3/4 str Prosobee
# ITEMID: 43403, Label: IV D10W BOLUS
# ITEMID: 43406, Label: .45 NS
# ITEMID: 43407, Label: Rectal irrigation
# ITEMID: 43418, Label: D10w BOLUS
# ITEMID: 43423, Label: D10W bolus
# ITEMID: 43424, Label: PE20 FS PO
# ITEMID: 43425, Label: PE20 PG
# ITEMID: 43426, Label: Subgaleal shunt dng
# ITEMID: 43432, Label: Similac w/ iron
# ITEMID: 43438, Label: D12.5 bolus
# ITEMID: 43439, Label: NG EAR 30cal
# ITEMID: 43440, Label: PO EAR30 cal
# ITEMID: 43444, Label: GT vent
# ITEMID: 43457, Label: PE24FSPO+MCT+Poly+PM
# ITEMID: 43461, Label: IV meds and flushes
# ITEMID: 43465, Label: Alimentum 28 NG
# ITEMID: 43466, Label: Alimentum 28 po
# ITEMID: 43469, Label: PE24FSNG+Promod+HMF
# ITEMID: 43470, Label: PE24FSPO+Promod+HMF
# ITEMID: 43471, Label: D10 Bolus
# ITEMID: 43472, Label: ur/kg/hr
# ITEMID: 43473, Label: IV Meds
# ITEMID: 43474, Label: GT
# ITEMID: 43475, Label: Prosobee 20cal GT
# ITEMID: 43476, Label: Prosobee 24cal GT
# ITEMID: 43485, Label: Nutramagen
# ITEMID: 43487, Label: Stomach asp.PH
# ITEMID: 43488, Label: Portagen 20cal
# ITEMID: 43493, Label: Umbi hernia
# ITEMID: 43497, Label: PE24+2HMF NG
# ITEMID: 43505, Label: PE24NG+MCT+Promod
# ITEMID: 43506, Label: PE24NG+2MCT+Promod
# ITEMID: 43507, Label: PE24PO+2MCT+Promod
# ITEMID: 43508, Label: ENFAMIL AR
# ITEMID: 43509, Label: ENFAMIL AR 28 cal
# ITEMID: 43514, Label: SIMILAC
# ITEMID: 43515, Label: NEOSURE 22
# ITEMID: 43516, Label: Neosure with 2 polye
# ITEMID: 43520, Label: ml/kg/day
# ITEMID: 43521, Label: ml/kg/hr
# ITEMID: 43526, Label: ur/cc/kg/hr
# ITEMID: 43532, Label: Needle Aspiration
# ITEMID: 43539, Label: repogle
# ITEMID: 43540, Label: PN D10.5W
# ITEMID: 43541, Label: Pregestimil 22cal NG
# ITEMID: 43542, Label: Pregestimil 22cal PO
# ITEMID: 43547, Label: urcc/kg/day
# ITEMID: 43548, Label: ur cc/kg/hr
# ITEMID: 43553, Label: PE22 PO
# ITEMID: 43555, Label: TPN D24
# ITEMID: 43571, Label: nitrates
# ITEMID: 43572, Label: drooling
# ITEMID: 43583, Label: UO/KG/hour
# ITEMID: 43584, Label: Sterile Water NG
# ITEMID: 43586, Label: D10w Bolus
# ITEMID: 43588, Label: .45%NS FLUSH
# ITEMID: 43590, Label: ur/cc/kg
# ITEMID: 43593, Label: IV D6W
# ITEMID: 43597, Label: Hep Flush
# ITEMID: 43598, Label: GT Pedialyte
# ITEMID: 43599, Label: Enfamil AR 24 GT
# ITEMID: 43616, Label: ALIMENTUM 24CAL
# ITEMID: 43619, Label: Bicarb
# ITEMID: 43622, Label: cc/kg
# ITEMID: 43631, Label: Neosure 22 NG
# ITEMID: 43632, Label: Neosure 22 PO
# ITEMID: 43636, Label: cc/k/h
# ITEMID: 43639, Label: UR.cc/kg/hr
# ITEMID: 43647, Label: UO cc/k/hour
# ITEMID: 43648, Label: D-10 Bolus
# ITEMID: 43649, Label: Cerebral Spinal Fld. LP
# ITEMID: 43656, Label: Sucrose
# ITEMID: 43657, Label: Similac 60/40
# ITEMID: 43661, Label: bicarb
# ITEMID: 43663, Label: .9% NS flush
# ITEMID: 43664, Label: PN-D11.5 with heparn
# ITEMID: 43674, Label: Sodium Phosphate IV
# ITEMID: 43677, Label: cyclosporin
# ITEMID: 43678, Label: APC
# ITEMID: 43683, Label: mucomyst
# ITEMID: 43689, Label: HD fluid removal
# ITEMID: 43693, Label: cyclosporin iv drip
# ITEMID: 43699, Label: d5 1/4 ns
# ITEMID: 43700, Label: Solumedrol mg/kg/min
# ITEMID: 43701, Label: ns with 2 amps bicab
# ITEMID: 43704, Label: er in
# ITEMID: 43707, Label: RLQ OPEN AREA
# ITEMID: 43708, Label: left groin site
# ITEMID: 43709, Label: L.ARM BAG
# ITEMID: 43712, Label: Pregesimil FS PO
# ITEMID: 43713, Label: Pregestilmil FS NG
# ITEMID: 43719, Label: golytle prep
# ITEMID: 43720, Label: ivf on medical floor
# ITEMID: 43725, Label: D5W 150meq Sod Bicar
# ITEMID: 43726, Label: cagluc (40gm/l)
# ITEMID: 43727, Label: bupivacaine.1% popli
# ITEMID: 43728, Label: bupivacaine.1% r axi
# ITEMID: 43733, Label: D5W & 40Gm CaGluc
# ITEMID: 43739, Label: OR INPUT CRYSTALLOID
# ITEMID: 43740, Label: EBL FROM OR
# ITEMID: 43744, Label: NS bladder pressure
# ITEMID: 43745, Label: k phos 15 mm
# ITEMID: 43746, Label: gastrografin
# ITEMID: 43747, Label: CALCIUM
# ITEMID: 43750, Label: ANGIO CRYSTTALOID
# ITEMID: 43757, Label: JT flush
# ...
# ITEMID: 46572, Label: 1/2 str Impact
# ITEMID: 46574, Label: CRRT rescue line NS
# ITEMID: 46577, Label: MULTIVITAMIN BAG
# ITEMID: 46582, Label: Nutren pulm w/Bene
# ITEMID: 46583, Label: tranexamic acid
# ITEMID: 46585, Label: D5W with 150MEQ HCO3
# ITEMID: 46588, Label: Rescue line
# ITEMID: 46589, Label: 1/2cc:cc 0.45% NS
# ITEMID: 46590, Label: Gastrografen
# ITEMID: 46591, Label: calcuim gluconate
# ITEMID: 46592, Label: soduim bicarbonate
# ITEMID: 46593, Label: MULTIVIT "BANANA"BAG
# ITEMID: 46594, Label: groin bag
# ITEMID: 46595, Label: left arm bag
# ITEMID: 46596, Label: left arm bag #1
# ITEMID: 46597, Label: left arm bag #2
# ITEMID: 46598, Label: right arm bag #1
# ITEMID: 46599, Label: OR Cell Saver
# ITEMID: 46600, Label: OR Plasmalyte
# ITEMID: 46602, Label: Sodabicarb Drip
# ITEMID: 46603, Label: Sodium Citrate ml/hr
# ITEMID: 46606, Label: ORAL SECRETION
# ITEMID: 46608, Label: K PHOS 15MMOL
# ITEMID: 46609, Label: bupivacaine
# ITEMID: 46610, Label: Contrast
# ITEMID: 46611, Label: POTASSIUM CHLOR 10MQ
# ITEMID: 46612, Label: E.R. prbc
# ITEMID: 46617, Label: Plasmalyte A
# ITEMID: 46618, Label: Emema
# ITEMID: 46624, Label: Anti-thymocyte Glob
# ITEMID: 46625, Label: octreotride
# ITEMID: 46630, Label: D10NSS
# ITEMID: 46632, Label: rescue line
# ITEMID: 46633, Label: KCL 10mmol in 100sw
# ITEMID: 46634, Label: EP lab intake
# ITEMID: 46635, Label: RESCUE FLUSH
# ITEMID: 46636, Label: CITRATE DEXTROSE 3%
# ITEMID: 46639, Label: pre arrival ivf
# ITEMID: 46641, Label: ANGIO INTIAKE
# ITEMID: 46643, Label: ns/40kcl
# ITEMID: 46644, Label: D5W & 150 MEQ NAHCO3
# ITEMID: 46651, Label: citrate dextrose
# ITEMID: 46653, Label: Flush Pack
# ITEMID: 46654, Label: Flexiseal Irrigant
# ITEMID: 46659, Label: Aline Site
# ITEMID: 46660, Label: sodiumphosphate15mmo
# ITEMID: 46662, Label: Right Shoulder
# ITEMID: 46665, Label: citrate gtt
# ITEMID: 46668, Label: 0.45%ns + 20 meq kcl
# ITEMID: 46669, Label: 0.45%NS +40meq kcl
# ITEMID: 46670, Label: 0.45% + 60 MEQ KCL
# ITEMID: 46671, Label: D50.45%NS + 60MQ KCL
# ITEMID: 46674, Label: 30mmol NaPhos
# ITEMID: 46677, Label: Flush
# ITEMID: 46679, Label: KCL 10 MEQ
# ITEMID: 46680, Label: Kphos 15 mmol
# ITEMID: 46681, Label: CRRT Rescue Flush
# ITEMID: 46682, Label: K Phos 15mmol
# ITEMID: 46683, Label: Bile refeeding via J
# ITEMID: 46684, Label: ER FFP
# ITEMID: 46685, Label: PD fluid
# ITEMID: 46686, Label: resue flush
# ITEMID: 46687, Label: acetylcystein
# ITEMID: 46688, Label: Floor NS Bolus
# ITEMID: 46689, Label: 30mmol Na Phos/D5W
# ITEMID: 46690, Label: bumetanide
# ITEMID: 46691, Label: Rescue Flush
# ITEMID: 46692, Label: isoproterenolmcg/min
# ITEMID: 46693, Label: prismasate
# ITEMID: 46694, Label: Abdominal VAC
# ITEMID: 46697, Label: Right Hand.
# ITEMID: 46698, Label: O.R. ASCITES
# ITEMID: 46699, Label: rt groin site
# ITEMID: 46700, Label: rt. fem site
# ITEMID: 46706, Label: Banana bag
# ITEMID: 46707, Label: blakemore
# ITEMID: 46708, Label: NS rescue flush
# ITEMID: 46714, Label: Filter flush - NS
# ITEMID: 46717, Label: NS with Sodium Phos
# ITEMID: 46720, Label: PD Dialysate
# ITEMID: 46725, Label: Methadone
# ITEMID: 46726, Label: Oral
# ITEMID: 46729, Label: Dextran
# ITEMID: 46730, Label: citrate/ACD
# ITEMID: 46731, Label: kcl 10meq/100cc
# ITEMID: 46736, Label: ER intake NS
# ITEMID: 46747, Label: Citrate Dextrose 3%
# ITEMID: 46749, Label: D5W/150MEQ NA BICARB
# ITEMID: 46750, Label: KCL 40 MEQ IN 500MLS
# ITEMID: 46753, Label: flushback
# ITEMID: 46754, Label: net pheresis intake
# ITEMID: 46758, Label: OR Intake
# ITEMID: 46762, Label: ED UOP
# ITEMID: 46765, Label: Replete w/Fib w/prot
# ITEMID: 46769, Label: cvvdh rescue line
# ITEMID: 46770, Label: OSH IVF
# ITEMID: 46771, Label: Ethacrynate Sodium
# ITEMID: 46772, Label: 3%CITRATE DEXTROSECF
# ITEMID: 46773, Label: CVVHD NS line flush
# ITEMID: 46774, Label: Sodabicarb Drip.
# ITEMID: 46776, Label: lactulose
# ITEMID: 46777, Label: ir intake
# ITEMID: 46778, Label: K-Phos
# ITEMID: 46780, Label: Bladdar pressure
# ITEMID: 46781, Label: lr bolus
# ITEMID: 46783, Label: 15mm k phos
# ITEMID: 46785, Label: ct insertion site
# ITEMID: 46789, Label: 3/4st impact/fiber
# ITEMID: 46790, Label: kcl 10 meq/100 ml  0
# ITEMID: 46791, Label: citrate infusion
# ITEMID: 46792, Label: Plasmalyte-A
# ITEMID: 46795, Label: NS Filter Flush
# ITEMID: 46797, Label: antithymocyteglobuli
# ITEMID: 46798, Label: 3% citrate
# ITEMID: 46800, Label: NS RESCUE
# ITEMID: 46802, Label: Farr 5 IV
# ITEMID: 46803, Label: Farr 5 po
# ITEMID: 46805, Label: Farr7
# ITEMID: 220862, Label: Albumin 25%
# ITEMID: 220864, Label: Albumin 5%
# ITEMID: 220949, Label: Dextrose 5%
# ITEMID: 220950, Label: Dextrose 10%
# ITEMID: 220952, Label: Dextrose 50%
# ITEMID: 220970, Label: Fresh Frozen Plasma
# ITEMID: 220995, Label: Sodium Bicarbonate 8.4%
# ITEMID: 221036, Label: Nutren Renal (Full)
# ITEMID: 221207, Label: Impact (Full)
# ITEMID: 221261, Label: Abciximab (Reopro)
# ITEMID: 221282, Label: Adenosine
# ITEMID: 221289, Label: Epinephrine
# ITEMID: 221319, Label: Alteplase (TPA)
# ITEMID: 221342, Label: Aminophylline
# ITEMID: 221347, Label: Amiodarone
# ITEMID: 221385, Label: Lorazepam (Ativan)
# ITEMID: 221393, Label: Atropine
# ITEMID: 221429, Label: Esmolol
# ITEMID: 221456, Label: Calcium Gluconate
# ITEMID: 221468, Label: Diltiazem
# ITEMID: 221555, Label: Cisatracurium
# ITEMID: 221623, Label: Diazepam (Valium)
# ITEMID: 221653, Label: Dobutamine
# ITEMID: 221662, Label: Dopamine
# ITEMID: 221668, Label: Midazolam (Versed)
# ITEMID: 221689, Label: Drotrecogin (Xigris)
# ITEMID: 221712, Label: Ketamine
# ITEMID: 221733, Label: Factor VIII
# ITEMID: 221744, Label: Fentanyl
# ITEMID: 221749, Label: Phenylephrine
# ITEMID: 221794, Label: Furosemide (Lasix)
# ITEMID: 221824, Label: Haloperidol (Haldol)
# ITEMID: 221828, Label: Hydralazine
# ITEMID: 221833, Label: Hydromorphone (Dilaudid)
# ITEMID: 221892, Label: Lepirudin
# ITEMID: 221906, Label: Norepinephrine
# ITEMID: 221986, Label: Milrinone
# ITEMID: 222011, Label: Magnesium Sulfate
# ITEMID: 222021, Label: Naloxone (Narcan)
# ITEMID: 222037, Label: Nesiritide
# ITEMID: 222042, Label: Nicardipine
# ITEMID: 222051, Label: Nitroprusside
# ITEMID: 222056, Label: Nitroglycerin
# ITEMID: 222062, Label: Vecuronium
# ITEMID: 222151, Label: Procainamide
# ITEMID: 222168, Label: Propofol
# ITEMID: 222190, Label: Ranitidine
# ITEMID: 222315, Label: Vasopressin
# ITEMID: 222318, Label: Verapamil
# ITEMID: 223257, Label: Insulin - 70/30
# ITEMID: 223258, Label: Insulin - Regular
# ITEMID: 223259, Label: Insulin - NPH
# ITEMID: 223260, Label: Insulin - Glargine
# ITEMID: 223261, Label: Insulin - Humalog 75/25
# ITEMID: 223262, Label: Insulin - Humalog
# ITEMID: 225147, Label: Argatroban
# ITEMID: 225148, Label: Bivalirudin (Angiomax)
# ITEMID: 225150, Label: Dexmedetomidine (Precedex)
# ITEMID: 225151, Label: Eptifibatide (Integrilin)
# ITEMID: 225152, Label: Heparin Sodium
# ITEMID: 225153, Label: Labetalol
# ITEMID: 225154, Label: Morphine Sulfate
# ITEMID: 225155, Label: Octreotide
# ITEMID: 225156, Label: Pentobarbital
# ITEMID: 225157, Label: Tirofiban (Aggrastat)
# ITEMID: 225158, Label: NaCl 0.9%
# ITEMID: 225159, Label: NaCl 0.45%
# ITEMID: 225161, Label: NaCl 3% (Hypertonic Saline)
# ITEMID: 225166, Label: Potassium Chloride
# ITEMID: 225167, Label: Hydrochloric Acid - HCL
# ITEMID: 225168, Label: Packed Red Blood Cells
# ITEMID: 225170, Label: Platelets
# ITEMID: 225171, Label: Cryoprecipitate
# ITEMID: 225173, Label: Cell Saver
# ITEMID: 225174, Label: Hetastarch (Hespan) 6%
# ITEMID: 225795, Label: Dextran 40
# ITEMID: 225797, Label: Free Water
# ITEMID: 225798, Label: Vancomycin
# ITEMID: 225799, Label: Gastric Meds
# ITEMID: 225801, Label: Lipids 20%
# ITEMID: 225823, Label: D5 1/2NS
# ITEMID: 225825, Label: D5NS
# ITEMID: 225827, Label: D5LR
# ITEMID: 225828, Label: LR
# ITEMID: 225830, Label: Multivitamins
# ITEMID: 225832, Label: Folic Acid
# ITEMID: 225833, Label: Thiamine
# ITEMID: 225834, Label: K Phos
# ITEMID: 225835, Label: Na Phos
# ITEMID: 225837, Label: Acyclovir
# ITEMID: 225838, Label: Ambisome
# ITEMID: 225840, Label: Amikacin
# ITEMID: 225842, Label: Ampicillin
# ITEMID: 225843, Label: Ampicillin/Sulbactam (Unasyn)
# ITEMID: 225844, Label: Atovaquone
# ITEMID: 225845, Label: Azithromycin
# ITEMID: 225847, Label: Aztreonam
# ITEMID: 225848, Label: Caspofungin
# ITEMID: 225850, Label: Cefazolin
# ITEMID: 225851, Label: Cefepime
# ITEMID: 225853, Label: Ceftazidime
# ITEMID: 225855, Label: Ceftriaxone
# ITEMID: 225859, Label: Ciprofloxacin
# ITEMID: 225860, Label: Clindamycin
# ITEMID: 225862, Label: Colistin
# ITEMID: 225863, Label: Daptomycin
# ITEMID: 225865, Label: Doxycycline
# ITEMID: 225866, Label: Erythromycin
# ITEMID: 225868, Label: Ethambutol
# ITEMID: 225869, Label: Fluconazole
# ITEMID: 225871, Label: Foscarnet
# ITEMID: 225873, Label: Gancyclovir
# ITEMID: 225875, Label: Gentamicin
# ITEMID: 225876, Label: Imipenem/Cilastatin
# ITEMID: 225877, Label: Isoniazid
# ITEMID: 225879, Label: Levofloxacin
# ITEMID: 225881, Label: Linezolid
# ITEMID: 225883, Label: Meropenem
# ITEMID: 225884, Label: Metronidazole
# ITEMID: 225885, Label: Micafungin
# ITEMID: 225886, Label: Moxifloxacin
# ITEMID: 225888, Label: Nafcillin
# ITEMID: 225889, Label: Oxacillin
# ITEMID: 225890, Label: Penicillin G potassium
# ITEMID: 225892, Label: Piperacillin
# ITEMID: 225893, Label: Piperacillin/Tazobactam (Zosyn)
# ITEMID: 225895, Label: Pyrazinamide
# ITEMID: 225896, Label: Quinine
# ITEMID: 225898, Label: Rifampin
# ITEMID: 225899, Label: Bactrim (SMX/TMP)
# ITEMID: 225902, Label: Tobramycin
# ITEMID: 225903, Label: Valgancyclovir
# ITEMID: 225905, Label: Voriconazole
# ITEMID: 225906, Label: Enoxaparin (Lovenox)
# ITEMID: 225907, Label: Famotidine (Pepcid)
# ITEMID: 225908, Label: Fondaparinux
# ITEMID: 225909, Label: Lansoprazole (Prevacid)
# ITEMID: 225910, Label: Pantoprazole (Protonix)
# ITEMID: 225911, Label: Ranitidine (Prophylaxis)
# ITEMID: 225912, Label: Carafate (Sucralfate)
# ITEMID: 225913, Label: Coumadin (Warfarin)
# ITEMID: 225914, Label: Factor VIIa
# ITEMID: 225915, Label: Profilnine
# ITEMID: 225916, Label: TPN w/ Lipids
# ITEMID: 225917, Label: TPN without Lipids
# ITEMID: 225920, Label: Peripheral Parenteral Nutrition
# ITEMID: 225928, Label: Impact with Fiber (Full)
# ITEMID: 225929, Label: ProBalance (Full)
# ITEMID: 225930, Label: Peptamen 1.5 (Full)
# ITEMID: 225931, Label: Nutren 2.0 (Full)
# ITEMID: 225934, Label: Vivonex (Full)
# ITEMID: 225935, Label: Replete (Full)
# ITEMID: 225936, Label: Replete with Fiber (Full)
# ITEMID: 225937, Label: Ensure (Full)
# ITEMID: 225941, Label: D5 1/4NS
# ITEMID: 225942, Label: Fentanyl (Concentrate)
# ITEMID: 225943, Label: Solution
# ITEMID: 225944, Label: Sterile Water
# ITEMID: 225945, Label: Lidocaine
# ITEMID: 225947, Label: Dextrose PN
# ITEMID: 225948, Label: Amino Acids
# ITEMID: 225969, Label: Lipids (additive)
# ITEMID: 225970, Label: Beneprotein
# ITEMID: 225973, Label: Meperidine (Demerol)
# ITEMID: 225974, Label: Metoprolol
# ITEMID: 225975, Label: Heparin Sodium (Prophylaxis)
# ITEMID: 225991, Label: Resource Fruit Beverage
# ITEMID: 225993, Label: Optisource
# ITEMID: 225994, Label: Mighty Shake (Vanilla/Strawberry)
# ITEMID: 225995, Label: Mighty Shake (Chocolate)
# ITEMID: 225996, Label: Mighty Shake (no sugar added)
# ITEMID: 226016, Label: Nutren 2.0 (1/4)
# ITEMID: 226017, Label: Nutren 2.0 (2/3)
# ITEMID: 226019, Label: Nutren 2.0 (1/2)
# ITEMID: 226020, Label: Impact (1/4)
# ITEMID: 226021, Label: Impact (2/3)
# ITEMID: 226022, Label: Impact (3/4)
# ITEMID: 226023, Label: Impact (1/2)
# ITEMID: 226024, Label: Impact with Fiber (1/4)
# ITEMID: 226026, Label: Impact with Fiber (3/4)
# ITEMID: 226027, Label: Impact with Fiber (1/2)
# ITEMID: 226028, Label: Nutren Renal (1/4)
# ITEMID: 226030, Label: Nutren Renal (3/4)
# ITEMID: 226031, Label: Nutren Renal (1/2)
# ITEMID: 226036, Label: Peptamen 1.5 (1/4)
# ITEMID: 226038, Label: Peptamen 1.5 (3/4)
# ITEMID: 226039, Label: Peptamen 1.5 (1/2)
# ITEMID: 226044, Label: Replete (1/4)
# ITEMID: 226045, Label: Replete (2/3)
# ITEMID: 226046, Label: Replete (3/4)
# ITEMID: 226047, Label: Replete (1/2)
# ITEMID: 226048, Label: Replete with Fiber (1/4)
# ITEMID: 226049, Label: Replete with Fiber (2/3)
# ITEMID: 226050, Label: Replete with Fiber (3/4)
# ITEMID: 226051, Label: Replete with Fiber (1/2)
# ITEMID: 226058, Label: Vivonex (3/4)
# ITEMID: 226059, Label: Vivonex (1/2)
# ITEMID: 226089, Label: Piggyback
# ITEMID: 226361, Label: Pre-Admission Intake
# ITEMID: 226363, Label: Cath Lab Intake
# ITEMID: 226364, Label: OR Crystalloid Intake
# ITEMID: 226365, Label: OR Colloid Intake
# ITEMID: 226367, Label: OR FFP Intake
# ITEMID: 226368, Label: OR Packed RBC Intake
# ITEMID: 226369, Label: OR Platelet Intake
# ITEMID: 226370, Label: OR Autologous Blood Intake
# ITEMID: 226371, Label: OR Cryoprecipitate Intake
# ITEMID: 226372, Label: OR Cell Saver Intake
# ITEMID: 226375, Label: PACU Crystalloid Intake
# ITEMID: 226376, Label: PACU Colloid Intake
# ITEMID: 226377, Label: PACU PO Intake
# ITEMID: 226452, Label: PO Intake
# ITEMID: 226453, Label: GT Flush
# ITEMID: 226875, Label: Ensure (3/4)
# ITEMID: 226877, Label: Ensure Plus (Full)
# ITEMID: 226880, Label: Nutren Pulmonary (Full)
# ITEMID: 226881, Label: Nutren Pulmonary (3/4)
# ITEMID: 226882, Label: Nutren Pulmonary (1/2)
# ITEMID: 227070, Label: PACU Packed RBC Intake
# ITEMID: 227071, Label: PACU Platelet Intake
# ITEMID: 227072, Label: PACU FFP Intake
# ITEMID: 227091, Label: Ensure (1/4)
# ITEMID: 227370, Label: Peptamen VHP (Full)
# ITEMID: 227518, Label: Nutren 2.0 (3/4)
# ITEMID: 227520, Label: Methadone Hydrochloride
# ITEMID: 227522, Label: KCL (Bolus)
# ITEMID: 227523, Label: Magnesium Sulfate (Bolus)
# ITEMID: 227524, Label: Magnesium Sulfate (OB-GYN)
# ITEMID: 227525, Label: Calcium Gluconate (CRRT)
# ITEMID: 227526, Label: Citrate
# ITEMID: 227528, Label: ACD-A Citrate (500ml)
# ITEMID: 227529, Label: ACD-A Citrate (1000ml)
# ITEMID: 227530, Label: IV Immune Globulin (IVIG)
# ITEMID: 227531, Label: Mannitol
# ITEMID: 227532, Label: Plasma Pheresis
# ITEMID: 227533, Label: Sodium Bicarbonate 8.4% (Amp)
# ITEMID: 227534, Label: Cyclosporine
# ITEMID: 227535, Label: Vitamin K (Phytonadione)
# ITEMID: 227536, Label: KCl (CRRT)
# ITEMID: 227689, Label: Dilantin
# ITEMID: 227690, Label: Fosphenytoin
# ITEMID: 227691, Label: Keflex
# ITEMID: 227692, Label: Isuprel
# ITEMID: 227694, Label: Omeprazole (Prilosec)
# ITEMID: 227695, Label: Fibersource HN (Full)
# ITEMID: 227696, Label: Fibersource HN (3/4)
# ITEMID: 227698, Label: Fibersource HN (1/2)
# ITEMID: 227699, Label: Fibersource HN (1/4)
# ITEMID: 227973, Label: NovaSource Renal (1/2)
# ITEMID: 227974, Label: NovaSource Renal (3/4)
# ITEMID: 227975, Label: NovaSource Renal (Full)
# ITEMID: 227976, Label: Boost Glucose Control (1/4)
# ITEMID: 227977, Label: Boost Glucose Control (1/2)
# ITEMID: 227978, Label: Boost Glucose Control (3/4)
# ITEMID: 227979, Label: Boost Glucose Control (Full)
# ITEMID: 228003, Label: Tamiflu
# ITEMID: 228131, Label: Isosource 1.5 (1/2)
# ITEMID: 228132, Label: Isosource 1.5 (1/4)
# ITEMID: 228133, Label: Isosource 1.5 (2/3)
# ITEMID: 228134, Label: Isosource 1.5 (3/4)
# ITEMID: 228135, Label: Isosource 1.5 (Full)
# ITEMID: 228140, Label: Dextrose 20%
# ITEMID: 228141, Label: Dextrose 30%
# ITEMID: 228142, Label: Dextrose 40%
# ITEMID: 228315, Label: Acetaminophen-IV
# ITEMID: 228316, Label: Keppra
# ITEMID: 228339, Label: Amiodarone 600/500
# ITEMID: 228340, Label: Furosemide (Lasix) 500/100
# ITEMID: 228341, Label: NaCl 23.4%
# ITEMID: 228348, Label: Nepro (1/2)
# ITEMID: 228351, Label: Nepro (Full)
# ITEMID: 228356, Label: Glucerna (1/2)
# ITEMID: 228359, Label: Glucerna (Full)
# ITEMID: 228361, Label: Pulmocare (1/4)
# ITEMID: 228363, Label: Pulmocare (Full)
# ITEMID: 228364, Label: Two Cal HN (1/2)
# ITEMID: 228367, Label: Two Cal HN (Full)
# ITEMID: 228383, Label: Peptamen Bariatric (Full)
#
# Total ICU Stays in Cohort: 34472
#
# Interventions in Your Cohort (Sorted by Number of Patients):
#       ITEMID              LABEL  num_patients  proportion
# 11     30013                D5W         18205    0.528110
# 47     30056          Po Intake         15400    0.446739
# 16     30018  .9% Normal Saline         15108    0.438269
# 1160  225158          NaCl 0.9%         12858    0.372998
# 1285  226452          PO Intake         10992    0.318867
# 1099  220949        Dextrose 5%         10765    0.312282
# 23     30026                KCL          8569    0.248579
# 1249  225943           Solution          8454    0.245243
# 115    30131           Propofol          7629    0.221310
# 120    30140                NaN          7302    0.211824

# %% [markdown]
# #### ***5. Update ITEMID Lists and Create Intervention Indicators***

# %% [markdown]
# ***Purpose: Update the ITEMID lists for vasopressors, antibiotics, and sedatives, and create binary indicators (has_vasopressor, has_antibiotic, has_sedative) for each intervention type.***

# %%
# Update ITEMID Lists and Create Intervention Indicators
# Updated ITEMID lists for each intervention type (based on previous analysis)
vasopressor_itemids = [221289, 221662, 221906, 221749, 222315]  # Epinephrine, Dopamine, Norepinephrine, Phenylephrine, Vasopressin
antibiotic_itemids = [225855, 225892, 225893, 225798]  # Ceftriaxone, Piperacillin, Piperacillin/Tazobactam, Vancomycin
sedative_itemids = [221668, 222168, 30131]  # Midazolam, Propofol (MV), Propofol (CV)

print("Updated Vasopressor ITEMIDs:", vasopressor_itemids)
print("Updated Antibiotic ITEMIDs:", antibiotic_itemids)
print("Updated Sedative ITEMIDs:", sedative_itemids)

# Ensure ICUSTAY_ID is integer and not null in both INPUTEVENTS_CV and INPUTEVENTS_MV
inputevents_cv = inputevents_cv[inputevents_cv['ICUSTAY_ID'].notnull()]
inputevents_cv['ICUSTAY_ID'] = inputevents_cv['ICUSTAY_ID'].astype(int)

inputevents_mv = inputevents_mv[inputevents_mv['ICUSTAY_ID'].notnull()]
inputevents_mv['ICUSTAY_ID'] = inputevents_mv['ICUSTAY_ID'].astype(int)

# Initialize the interventions DataFrame with icustay_id
interventions = merged_data[['icustay_id']].copy()

# 1. Vasopressor Indicator
cv_vasopressor = inputevents_cv[inputevents_cv['ITEMID'].isin(vasopressor_itemids)].groupby('ICUSTAY_ID').size().reset_index(name='vasopressor_events')
mv_vasopressor = inputevents_mv[inputevents_mv['ITEMID'].isin(vasopressor_itemids)].groupby('ICUSTAY_ID').size().reset_index(name='vasopressor_events')
vasopressor = pd.concat([cv_vasopressor, mv_vasopressor]).groupby('ICUSTAY_ID')['vasopressor_events'].sum().reset_index()
interventions = interventions.merge(vasopressor, left_on='icustay_id', right_on='ICUSTAY_ID', how='left')
interventions['has_vasopressor'] = (interventions['vasopressor_events'].fillna(0) > 0).astype(int)

# 2. Antibiotic Indicator
cv_antibiotic = inputevents_cv[inputevents_cv['ITEMID'].isin(antibiotic_itemids)].groupby('ICUSTAY_ID').size().reset_index(name='antibiotic_events')
mv_antibiotic = inputevents_mv[inputevents_mv['ITEMID'].isin(antibiotic_itemids)].groupby('ICUSTAY_ID').size().reset_index(name='antibiotic_events')
antibiotic = pd.concat([cv_antibiotic, mv_antibiotic]).groupby('ICUSTAY_ID')['antibiotic_events'].sum().reset_index()
interventions = interventions.merge(antibiotic, left_on='icustay_id', right_on='ICUSTAY_ID', how='left')
interventions['has_antibiotic'] = (interventions['antibiotic_events'].fillna(0) > 0).astype(int)

# 3. Sedative Indicator
cv_sedative = inputevents_cv[inputevents_cv['ITEMID'].isin(sedative_itemids)].groupby('ICUSTAY_ID').size().reset_index(name='sedative_events')
mv_sedative = inputevents_mv[inputevents_mv['ITEMID'].isin(sedative_itemids)].groupby('ICUSTAY_ID').size().reset_index(name='sedative_events')
sedative = pd.concat([cv_sedative, mv_sedative]).groupby('ICUSTAY_ID')['sedative_events'].sum().reset_index()
interventions = interventions.merge(sedative, left_on='icustay_id', right_on='ICUSTAY_ID', how='left')
interventions['has_sedative'] = (interventions['sedative_events'].fillna(0) > 0).astype(int)

# Clean up interventions DataFrame
interventions = interventions.drop(columns=['ICUSTAY_ID_x', 'ICUSTAY_ID_y', 'ICUSTAY_ID', 'vasopressor_events', 'antibiotic_events', 'sedative_events'], errors='ignore')

# Print the interventions DataFrame
print("\nInterventions DataFrame:")
print(interventions.head())
# Out:
# Updated Vasopressor ITEMIDs: [221289, 221662, 221906, 221749, 222315]
# Updated Antibiotic ITEMIDs: [225855, 225892, 225893, 225798]
# Updated Sedative ITEMIDs: [221668, 222168, 30131]
#
# Interventions DataFrame:
#    icustay_id  has_vasopressor  has_antibiotic  has_sedative
# 0      211552                0               0             0
# 1      294638                0               0             0
# 2      228232                0               0             0
# 3      220597                0               0             1
# 4      229441                0               0             0

# %% [markdown]
# #### ***Define final_data and add intervention indicators***

# %% [markdown]
# ***Purpose: Define final_data as a copy of merged_data, merge the intervention indicators, and verify the new columns and their distributions.***

# %%
# Define final_data as merged_data (if not already defined)
final_data = merged_data.copy()

# Update final_data with the new indicators
final_data = final_data.drop(columns=['has_vasopressor', 'has_antibiotic', 'has_sedative'], errors='ignore')
final_data = final_data.merge(interventions[['icustay_id', 'has_vasopressor', 'has_antibiotic', 'has_sedative']], on='icustay_id', how='left')

# Verify distributions
print("Distributions of Updated Interventions:")
for intervention in ['has_vasopressor', 'has_antibiotic', 'has_sedative']:
    print(f"\n{intervention}:")
    print(final_data[intervention].value_counts(normalize=True))
# Out:
# Distributions of Updated Interventions:
#
# has_vasopressor:
# has_vasopressor
# 0    0.879148
# 1    0.120852
# Name: proportion, dtype: float64
#
# has_antibiotic:
# has_antibiotic
# 0    0.837433
# 1    0.162567
# Name: proportion, dtype: float64
#
# has_sedative:
# has_sedative
# 0    0.593525
# 1    0.406475
# Name: proportion, dtype: float64

# %%
# Load ICUSTAYS and PATIENTS tables
icustays = pd.read_csv('C:/MIMIC-III/mimic-iii-clinical-database-1.4/data/ICUSTAYS.csv')
patients = pd.read_csv('C:/MIMIC-III/mimic-iii-clinical-database-1.4/data/PATIENTS.csv')

# Merge ICUSTAYS with PATIENTS to get admission and death dates
icustays = icustays.merge(patients[['SUBJECT_ID', 'DOD']], on='SUBJECT_ID', how='left')

# Calculate time from ICU admission (INTIME) to death (DOD)
icustays['INTIME'] = pd.to_datetime(icustays['INTIME'])
icustays['DOD'] = pd.to_datetime(icustays['DOD'])
icustays['days_to_death'] = (icustays['DOD'] - icustays['INTIME']).dt.total_seconds() / (24 * 60 * 60)

# Define 30-day survival
# If days_to_death is NaN (patient survived) or > 30, they survived 30 days
icustays['surv_30d'] = ((icustays['days_to_death'].isna()) | (icustays['days_to_death'] > 30)).astype(int)

# Merge with final_data
final_data = final_data.merge(icustays[['ICUSTAY_ID', 'surv_30d']], left_on='icustay_id', right_on='ICUSTAY_ID', how='left')
final_data = final_data.drop(columns=['ICUSTAY_ID'], errors='ignore')

# Verify the outcome
print("Distribution of 30-Day ICU Survival:")
print(final_data['surv_30d'].value_counts(normalize=True))
# Out:
# Distribution of 30-Day ICU Survival:
# surv_30d
# 1    0.875754
# 0    0.124246
# Name: proportion, dtype: float64

# %%
print("\nMissing Value Counts and Percentages for Each Variable:")
total_rows = len(final_data)

for col in final_data.columns:
    missing_count = final_data[col].isna().sum()  # Count of missing values
    missing_percent = (missing_count / total_rows) * 100  # Percentage of missing values
    print(f"{col}: {missing_count} missing ({missing_percent:.2f}%)")
# Out:
# Shape of final_data: (34472, 140)
#
# Missing Value Counts and Percentages for Each Variable:
# icustay_id: 0 missing (0.00%)
# subject_id: 0 missing (0.00%)
# hadm_id: 0 missing (0.00%)
# gender: 0 missing (0.00%)
# ethnicity: 0 missing (0.00%)
# age: 0 missing (0.00%)
# insurance: 0 missing (0.00%)
# admittime: 0 missing (0.00%)
# diagnosis_at_admission: 1 missing (0.00%)
# dischtime: 0 missing (0.00%)
# discharge_location: 0 missing (0.00%)
# fullcode_first: 6310 missing (18.30%)
# dnr_first: 6310 missing (18.30%)
# fullcode: 6310 missing (18.30%)
# dnr: 6310 missing (18.30%)
# dnr_first_charttime: 31353 missing (90.95%)
# timecmo_chart: 33514 missing (97.22%)
# cmo_first: 6310 missing (18.30%)
# cmo_last: 6310 missing (18.30%)
# cmo: 6310 missing (18.30%)
# deathtime: 31122 missing (90.28%)
# intime: 0 missing (0.00%)
# outtime: 0 missing (0.00%)
# los_icu: 0 missing (0.00%)
# admission_type: 0 missing (0.00%)
# first_careunit: 0 missing (0.00%)
# mort_icu: 0 missing (0.00%)
# mort_hosp: 0 missing (0.00%)
# hospital_expire_flag: 0 missing (0.00%)
# hospstay_seq: 0 missing (0.00%)
# readmission_30: 0 missing (0.00%)
# Alanine aminotransferase_mean: 18326 missing (53.16%)
# Albumin_mean: 20408 missing (59.20%)
# Albumin ascites_mean: 34368 missing (99.70%)
# Albumin pleural_mean: 34331 missing (99.59%)
# Albumin urine_mean: 34348 missing (99.64%)
# Alkaline phosphate_mean: 18719 missing (54.30%)
# Anion gap_mean: 589 missing (1.71%)
# Asparate aminotransferase_mean: 18344 missing (53.21%)
# Basophils_mean: 19958 missing (57.90%)
# Bicarbonate_mean: 251 missing (0.73%)
# Bilirubin_mean: 18457 missing (53.54%)
# Blood urea nitrogen_mean: 127 missing (0.37%)
# CO2_mean: 15022 missing (43.58%)
# CO2 (ETCO2, PCO2, etc.)_mean: 12024 missing (34.88%)
# Calcium_mean: 3662 missing (10.62%)
# Calcium ionized_mean: 16836 missing (48.84%)
# Calcium urine_mean: 34291 missing (99.47%)
# Cardiac Index_mean: 30026 missing (87.10%)
# Cardiac Output Thermodilution_mean: 30357 missing (88.06%)
# Cardiac Output fick_mean: 31913 missing (92.58%)
# Central Venous Pressure_mean: 22782 missing (66.09%)
# Chloride_mean: 207 missing (0.60%)
# Chloride urine_mean: 32316 missing (93.75%)
# Cholesterol_mean: 31420 missing (91.15%)
# Cholesterol HDL_mean: 31508 missing (91.40%)
# Cholesterol LDL_mean: 31652 missing (91.82%)
# Creatinine_mean: 125 missing (0.36%)
# Creatinine ascites_mean: 34411 missing (99.82%)
# Creatinine body fluid_mean: 34442 missing (99.91%)
# Creatinine pleural_mean: 34431 missing (99.88%)
# Creatinine urine_mean: 29073 missing (84.34%)
# Diastolic blood pressure_mean: 203 missing (0.59%)
# Eosinophils_mean: 34105 missing (98.94%)
# Fibrinogen_mean: 24352 missing (70.64%)
# Fraction inspired oxygen_mean: 25983 missing (75.37%)
# Fraction inspired oxygen Set_mean: 23958 missing (69.50%)
# Glascow coma scale total_mean: 14951 missing (43.37%)
# Glucose_mean: 99 missing (0.29%)
# Heart Rate_mean: 202 missing (0.59%)
# Height_mean: 26884 missing (77.99%)
# Hematocrit_mean: 118 missing (0.34%)
# Hemoglobin_mean: 167 missing (0.48%)
# Lactate_mean: 14146 missing (41.04%)
# Lactate dehydrogenase_mean: 23828 missing (69.12%)
# Lactate dehydrogenase pleural_mean: 34132 missing (99.01%)
# Lactic acid_mean: 19051 missing (55.27%)
# Lymphocytes_mean: 16530 missing (47.95%)
# Lymphocytes ascites_mean: 34114 missing (98.96%)
# Lymphocytes atypical_mean: 32801 missing (95.15%)
# Lymphocytes atypical CSL_mean: 34432 missing (99.88%)
# Lymphocytes body fluid_mean: 33995 missing (98.62%)
# Lymphocytes percent_mean: 34334 missing (99.60%)
# Lymphocytes pleural_mean: 34136 missing (99.03%)
# Magnesium_mean: 1366 missing (3.96%)
# Mean blood pressure_mean: 203 missing (0.59%)
# Mean corpuscular hemoglobin_mean: 345 missing (1.00%)
# Mean corpuscular hemoglobin concentration_mean: 344 missing (1.00%)
# Mean corpuscular volume_mean: 345 missing (1.00%)
# Monocytes_mean: 16635 missing (48.26%)
# Monocytes CSL_mean: 33911 missing (98.37%)
# Neutrophils_mean: 16495 missing (47.85%)
# Oxygen saturation_mean: 101 missing (0.29%)
# Partial pressure of carbon dioxide_mean: 12025 missing (34.88%)
# Partial pressure of oxygen_mean: 22770 missing (66.05%)
# Partial thromboplastin time_mean: 3111 missing (9.02%)
# Peak inspiratory pressure_mean: 19299 missing (55.98%)
# Phosphate_mean: 3651 missing (10.59%)
# Phosphorous_mean: 4164 missing (12.08%)
# Plateau Pressure_mean: 20874 missing (60.55%)
# Platelets_mean: 214 missing (0.62%)
# Positive end-expiratory pressure_mean: 25714 missing (74.59%)
# Positive end-expiratory pressure Set_mean: 18505 missing (53.68%)
# Post Void Residual_mean: 33918 missing (98.39%)
# Potassium_mean: 127 missing (0.37%)
# Potassium serum_mean: 18159 missing (52.68%)
# Prothrombin time INR_mean: 3018 missing (8.75%)
# Prothrombin time PT_mean: 3026 missing (8.78%)
# Pulmonary Artery Pressure mean_mean: 32814 missing (95.19%)
# Pulmonary Artery Pressure systolic_mean: 27816 missing (80.69%)
# Pulmonary Capillary Wedge Pressure_mean: 33312 missing (96.63%)
# Red blood cell count_mean: 328 missing (0.95%)
# Red blood cell count CSF_mean: 33881 missing (98.29%)
# Red blood cell count ascites_mean: 34111 missing (98.95%)
# Red blood cell count pleural_mean: 34142 missing (99.04%)
# Red blood cell count urine_mean: 29708 missing (86.18%)
# Respiratory rate_mean: 229 missing (0.66%)
# Respiratory rate Set_mean: 19655 missing (57.02%)
# Sodium_mean: 128 missing (0.37%)
# Systemic Vascular Resistance_mean: 30206 missing (87.62%)
# Systolic blood pressure_mean: 203 missing (0.59%)
# Temperature_mean: 288 missing (0.84%)
# Tidal Volume Observed_mean: 18527 missing (53.75%)
# Tidal Volume Set_mean: 19759 missing (57.32%)
# Tidal Volume Spontaneous_mean: 21408 missing (62.10%)
# Total Protein_mean: 34082 missing (98.87%)
# Total Protein Urine_mean: 33692 missing (97.74%)
# Troponin-I_mean: 33473 missing (97.10%)
# Troponin-T_mean: 24743 missing (71.78%)
# Venous PvO2_mean: 33781 missing (98.00%)
# Weight_mean: 8850 missing (25.67%)
# White blood cell count_mean: 271 missing (0.79%)
# White blood cell count urine_mean: 29770 missing (86.36%)
# pH_mean: 10862 missing (31.51%)
# pH urine_mean: 17114 missing (49.65%)
# icd9_codes: 0 missing (0.00%)
# has_vasopressor: 0 missing (0.00%)
# has_antibiotic: 0 missing (0.00%)
# has_sedative: 0 missing (0.00%)
# surv_30d: 0 missing (0.00%)

# %%
output_path = "C:/MIMIC-Extract/processed_final_data.csv"

try:
    final_data.to_csv(output_path, index=False)
    print(f"Data saved to {output_path}")
except NameError:
    raise Exception("final_data not found in memory. Please provide the DataFrame variable name.")
# Out:
# Data saved to C:/MIMIC-Extract/processed_final_data.csv
